# %%
# [Deep contextualized word representations](https://arxiv.org/pdf/1802.05365.pdf)
from tensorflow import keras
import tensorflow as tf
import utils    # this refers to utils.py in my [repo](https://github.com/MorvanZhou/NLP-Tutorials/)
import time
import os

class ELMo(keras.Model):
    def __init__(self, v_dim, emb_dim, units, n_layers, lr):
        super().__init__()
        self.n_layers = n_layers
        self.units = units

        # encoder
        self.word_embed = keras.layers.Embedding(
            input_dim=v_dim, output_dim=emb_dim,  # [n_vocab, emb_dim]
            embeddings_initializer=keras.initializers.RandomNormal(0., 0.001),
            mask_zero=True,
        )
        # forward lstm
        self.fs = [keras.layers.LSTM(units, return_sequences=True) for _ in range(n_layers)]
        self.f_logits = keras.layers.Dense(v_dim)
        # backward lstm
        self.bs = [keras.layers.LSTM(units, return_sequences=True, go_backwards=True) for _ in range(n_layers)]
        self.b_logits = keras.layers.Dense(v_dim)

        self.cross_entropy1 = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
        self.cross_entropy2 = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
        self.opt = keras.optimizers.Adam(lr)

    def call(self, seqs):
        embedded = self.word_embed(seqs)        # [n, step, dim]
        """
        0123    forward
        1234    forward predict
         1234   backward 
         0123   backward predict
        """
        mask = self.word_embed.compute_mask(seqs)
        fxs, bxs = [embedded[:, :-1]], [embedded[:, 1:]]
        for fl, bl in zip(self.fs, self.bs):
            fx = fl(
                fxs[-1], mask=mask[:, :-1], initial_state=fl.get_initial_state(fxs[-1])
            )           # [n, step-1, dim]
            bx = bl(
                bxs[-1], mask=mask[:, 1:], initial_state=bl.get_initial_state(bxs[-1])
            )  # [n, step-1, dim]
            fxs.append(fx)      # predict 1234
            bxs.append(tf.reverse(bx, axis=[1]))    # predict 0123
        return fxs, bxs

    def step(self, seqs):
        with tf.GradientTape() as tape:
            fxs, bxs = self.call(seqs)
            fo, bo = self.f_logits(fxs[-1]), self.b_logits(bxs[-1])
            loss = (self.cross_entropy1(seqs[:, 1:], fo) + self.cross_entropy2(seqs[:, :-1], bo))/2
        grads = tape.gradient(loss, self.trainable_variables)
        self.opt.apply_gradients(zip(grads, self.trainable_variables))
        return loss, (fo, bo)

    def get_emb(self, seqs):
        fxs, bxs = self.call(seqs)
        xs = [tf.concat((f[:, :-1, :], b[:, 1:, :]), axis=2).numpy() for f, b in zip(fxs, bxs)]
        for x in xs:
            print("layers shape=", x.shape)
        return xs


def train(model, data, step):
    t0 = time.time()
    for t in range(step):
        seqs = data.sample(BATCH_SIZE)
        loss, (fo, bo) = model.step(seqs)
        if t % 80 == 0:
            fp = fo[0].numpy().argmax(axis=1)
            bp = bo[0].numpy().argmax(axis=1)
            t1 = time.time()
            print(
                "\n\nstep: ", t,
                "| time: %.2f" % (t1 - t0),
                "| loss: %.3f" % loss.numpy(),
                "\n| tgt: ", " ".join([data.i2v[i] for i in seqs[0] if i != data.pad_id]),
                "\n| f_prd: ", " ".join([data.i2v[i] for i in fp if i != data.pad_id]),
                "\n| b_prd: ", " ".join([data.i2v[i] for i in bp if i != data.pad_id]),
                )
            t0 = t1
    os.makedirs("./visual/models/elmo", exist_ok=True)
    model.save_weights("./visual/models/elmo/model.ckpt")


def export_w2v(model, data):
    model.load_weights("./visual/models/elmo/model.ckpt")
    emb = model.get_emb(data.sample(4))
    print(emb)


if __name__ == "__main__":
    #utils.set_soft_gpu(True)
    UNITS = 256
    N_LAYERS = 2
    BATCH_SIZE = 16
    LEARNING_RATE = 2e-3
    d = utils.MRPCSingle("./MRPC", rows=2000)
    print("num word: ", d.num_word)
    m = ELMo(d.num_word, emb_dim=UNITS, units=UNITS, n_layers=N_LAYERS, lr=LEARNING_RATE)
    train(m, d, 10000)
    export_w2v(m, d)
# Out:
# downloading from https://mofanpy.com/static/files/MRPC/msr_paraphrase_train.txt
# completed
# downloading from https://mofanpy.com/static/files/MRPC/msr_paraphrase_test.txt
# completed
# num word:  12880
#
#
# step:  0 | time: 29.60 | loss: 9.463
# | tgt:  <GO> still , changes to ie <quote> may affect a large number of existing web pages , <quote> according to the w3c 's notice . <SEP>
# | f_prd:  alarm cd suffering suffering suffering expectation expectation movies movies movies movies gromer gromer gromer gromer gromer gromer gromer gromer vc vc vc dulles dulles actual actual
# | b_prd:  alive alive covello d-waco d-waco d-waco d-waco president president president payload payload payload payload payload admiral admiral downstairs guatemala guatemala reis viability viability viability barometer
#
#
# step:  80 | time: 8.96 | loss: 7.752
# | tgt:  <GO> many compensation experts had predicted that carty would get a generous severance package because his voluntary resignation helped preserve the concessions , the fort worth star-telegram reported . <SEP>
# | f_prd:  , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# | b_prd:  , , , , , , , , , , , , , , , , , , , , , , , , , , , , , <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  160 | time: 8.97 | loss: 7.844
# | tgt:  <GO> according to the affidavit , al-amoudi made at least <NUM> trips to libya using two american and one yemeni passport . <SEP>
# | f_prd:  , , , , , , , , , , , , , , , , , , , , , , ,
# | b_prd:  , , , , , , , , , , , , , , , , , , , , , . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  240 | time: 8.95 | loss: 7.358
# | tgt:  <GO> two women lost their battle in a british court yesterday to save their frozen embryos and use them to have children without the consent of their former partners . <SEP>
# | f_prd:  the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# | b_prd:  the the the the the the the the the the the the the the the the the the the the the the the the the the the the the . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  320 | time: 8.97 | loss: 7.372
# | tgt:  <GO> the worst-affected area was south kyongsang province where at least <NUM> people drowned and roads were swept away . <SEP>
# | f_prd:  the <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the . . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  400 | time: 8.99 | loss: 7.565
# | tgt:  <GO> associated press writers michelle morgante in san diego and ken ritter in las vegas contributed to this article . <SEP>
# | f_prd:  the , , , , , , , , , , , , , , , , , , , ,
# | b_prd:  , , , , , , , , , , , , , , , , , , , . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  480 | time: 8.94 | loss: 7.264
# | tgt:  <GO> the stretch of danube river passing through the balkans dropped so low that wrecks of world war ii boats became visible . <SEP>
# | f_prd:  the the , , , , , , , , , , , , , , , , , , , , , ,
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the the the the the the the the the . . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  560 | time: 8.93 | loss: 7.013
# | tgt:  <GO> supporters asked a federal court monday to block the removal of a ten commandments monument from the alabama judicial building . <SEP>
# | f_prd:  the , the , , , , , the , , the , , . . the . . . . . .
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the , the the the the . . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  640 | time: 8.93 | loss: 6.773
# | tgt:  <GO> the blue-chip dow jones industrial average .dji edged down <NUM> points , or <NUM> percent , at <NUM> . <SEP>
# | f_prd:  the , the , , , , , , the , <SEP> the <SEP> <SEP> <SEP> the the <SEP> <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> the the , the <NUM> <NUM> <NUM> the <NUM> <NUM> <NUM> the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  720 | time: 8.99 | loss: 6.554
# | tgt:  <GO> officials in malawi said the men were on the cia 's ' ' watch list ' ' since the twin <NUM> bombings at the us embassies in kenya and tanzania . <SEP>
# | f_prd:  the the the the the , , , the , , , the the the , the the the , , . . the . . . the . . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> , <GO> the <NUM> <NUM> <NUM> the , <NUM> <NUM> <NUM> the the the <NUM> <NUM> the the , <NUM> the <NUM> the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  800 | time: 9.02 | loss: 6.585
# | tgt:  <GO> the official , who spoke on condition of anonymity , said that two iraqis and two saudis detained after the attack gave information leading to the arrest of the others . <SEP>
# | f_prd:  the the , the , , the , the , the the the , , the . . . the . . the . the the . . the . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> , , the the , , , , the , <NUM> the the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  880 | time: 9.09 | loss: 6.354
# | tgt:  <GO> none of the casualties was americans , said capt. michael calvert , regiment spokesman . <SEP>
# | f_prd:  the , the , , the , the the the , , the . . <SEP>
# | b_prd:  the , <GO> the , <NUM> <NUM> , the to the <NUM> , , <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  960 | time: 9.08 | loss: 6.342
# | tgt:  <GO> <quote> craxi begged me to intervene because he believed the operation damaged the state , <quote> mr berlusconi said . <SEP>
# | f_prd:  the the , , , the , the , the the , , said , the the said , . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> the <GO> the , , the , to the <NUM> , the , <NUM> <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1040 | time: 9.03 | loss: 5.988
# | tgt:  <GO> the nist discovered that in <NUM> the port authority issued guidelines to upgrade the fireproofing to a thickness of <NUM> 1 / <NUM> inches . <SEP>
# | f_prd:  the the , , the the , the the , , , the the the , the the . the . . <SEP> . . <SEP>
# | b_prd:  <GO> <GO> <GO> <NUM> <GO> the <GO> the , , , , , to the , to the <NUM> $ <NUM> <NUM> the <NUM> <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1120 | time: 8.99 | loss: 5.840
# | tgt:  <GO> the federal government is approving new pesticides without even knowing whether they pose a threat to children , canada 's environment watchdog warned yesterday . <SEP>
# | f_prd:  the the the , the the the , the the the the said the the , the , the . . . . . . <SEP>
# | b_prd:  <GO> the <GO> <GO> <GO> the the <GO> <GO> , <GO> <GO> , , the , the <NUM> the , the <NUM> , <NUM> said . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1200 | time: 8.93 | loss: 5.548
# | tgt:  <GO> there was no immediate evidence that the two incidents were connected , police said . <SEP>
# | f_prd:  the , the the the , the not , , the . the . . <SEP>
# | b_prd:  <GO> , <GO> the the , of the the , the <NUM> , , said . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1280 | time: 8.92 | loss: 5.600
# | tgt:  <GO> according to sanmina-sci , newisys , based in austin , texas , will become a wholly-owned subsidiary . <SEP>
# | f_prd:  the <NUM> <NUM> , the , the , the , the , the the the be , , <SEP>
# | b_prd:  , , , <NUM> , <NUM> , , the <NUM> in <NUM> , to in the stock said . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1360 | time: 9.08 | loss: 5.499
# | tgt:  <GO> <quote> i think <NUM> percent of the work is already done , <quote> tauzin told reporters in the capitol . <SEP>
# | f_prd:  the the said the , , <NUM> <NUM> , the the to <NUM> <NUM> said the , the nasdaq year <SEP>
# | b_prd:  , <GO> was $ <NUM> <NUM> , , , , , <NUM> , , , to <NUM> in the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1440 | time: 9.01 | loss: 5.336
# | tgt:  <GO> with the economy sluggish , producers have had a tough time trying to raise prices . <SEP>
# | f_prd:  the the jones , , the , not the not , in to the the . <SEP>
# | b_prd:  <GO> <GO> the the <NUM> the has it , the a be , to stock said . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1520 | time: 9.00 | loss: 5.185
# | tgt:  <GO> seiu president andrew stern said the unions are <quote> totally comfortable <quote> with dean 's positions . <SEP>
# | f_prd:  the the said jones that the first , the the said the in the 's be . <SEP>
# | b_prd:  <GO> <GO> <GO> , , <GO> the he , and and , , , , a <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1600 | time: 9.09 | loss: 5.199
# | tgt:  <GO> but chauncey billups demonstrated he 's also capable of big games , scoring <NUM> points over the final two games against the magic . <SEP>
# | f_prd:  the the the jones the said not said , the company , <quote> the percent , <NUM> new year year . the new . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> , , united shares , <NUM> <NUM> , $ <NUM> , in the of united <NUM> in the said .
#
#
# step:  1680 | time: 9.11 | loss: 5.129
# | tgt:  <GO> bush said resistance forces hostile to the u.s. presence <quote> feel like ... the conditions are such that they can attack us there . <SEP>
# | f_prd:  the 's the said , , be company states , the the the the united , not the the said not in said . <SEP>
# | b_prd:  <GO> , <GO> it in , in the a , would is to , and he be , <quote> , the the , said .
#
#
# step:  1760 | time: 9.07 | loss: 4.780
# | tgt:  <GO> under the proposed terms of the transaction , and following the spinoff of palmsource , palm will exchange <NUM> shares for each share of handspring . <SEP>
# | f_prd:  the the jones dow , the <NUM> of the <NUM> <NUM> <NUM> of the , <NUM> , be , , . the . . the . <SEP>
# | b_prd:  <GO> <GO> the the <NUM> <GO> the <NUM> , <GO> in the shares , <NUM> , , new the the <NUM> on the <NUM> in said .
#
#
# step:  1840 | time: 9.12 | loss: 4.738
# | tgt:  <GO> max guarino , <NUM> , was found april <NUM> in the water off city island . <SEP>
# | f_prd:  the states , the , the the the <NUM> million the nasdaq of in . . <SEP>
# | b_prd:  <GO> & <NUM> , <NUM> , was at $ <NUM> of the the new <NUM> said .
#
#
# step:  1920 | time: 9.01 | loss: 4.595
# | tgt:  <GO> <quote> such communication will help adult smokers make more informed choices , <quote> company vice president richard verheij told a house energy and commerce subcommittee at a separate hearing . <SEP>
# | f_prd:  the i i said be in be the the than , in the said said the , , said the company 's , the 's . the statement . . <SEP>
# | b_prd:  <GO> <GO> the it to of <GO> to <GO> is in said <GO> the chief chief chief the it , a for , the been , in a the <NUM> .
#
#
# step:  2000 | time: 9.03 | loss: 4.717
# | tgt:  <GO> authorities had no leads in biggs ' death until four months later , when a tipster said mallard talked about the incident at a party . <SEP>
# | f_prd:  the said a <NUM> in the 's 't , the years , , the the company said that week to the war . the war . <SEP>
# | b_prd:  the he <GO> a <GO> in , a <GO> in <NUM> said said , , the , , he , in the , in a said .
#
#
# step:  2080 | time: 8.95 | loss: 4.545
# | tgt:  <GO> france , which infuriated washington by leading the charge against u.n. approval for the war , also sought changes . <SEP>
# | f_prd:  the , the said <NUM> , the the <NUM> in the years to the united , <quote> said to . <SEP>
# | b_prd:  <GO> <NUM> , has in washington to of the charge the the , of the <NUM> , <quote> the said .
#
#
# step:  2160 | time: 8.98 | loss: 4.204
# | tgt:  <GO> the technology-laced nasdaq composite index .ixic rose <NUM> points , or <NUM> percent , to <NUM> , after losing more than <NUM> percent on tuesday . <SEP>
# | f_prd:  the dow jones composite index .ixic > <NUM> points , or <NUM> percent , to <NUM> . according <NUM> <NUM> <NUM> <NUM> . , $ . <SEP>
# | b_prd:  <GO> the technology-laced nasdaq composite index index down <NUM> points , or <NUM> percent , $ percent , was from more or <NUM> percent on said .
#
#
# step:  2240 | time: 8.95 | loss: 4.128
# | tgt:  <GO> in <NUM> a california legislator proposed a law requiring driving tests for those over the age of <NUM> who sought to renew their licenses . <SEP>
# | f_prd:  the the , troops , was the first , be been in the or the united to the , have to be the year . <SEP>
# | b_prd:  <GO> $ <GO> a the the <GO> a skin was be blamed of was in the <NUM> $ , has according to in the said .
#
#
# step:  2320 | time: 8.97 | loss: 4.039
# | tgt:  <GO> the pg-13 sequel <quote> <NUM> fast <NUM> furious <quote> raked in an estimated $ <NUM> million during its opening weekend , jumping over last weekend 's catch , <quote> finding nemo . <quote> <SEP>
# | f_prd:  the technology-laced & a the percent , , in the to the first the <NUM> million of the yield york , <quote> to the year , first , said said said , <SEP> <SEP>
# | b_prd:  <GO> the shares <GO> $ with $ <NUM> , been appear of an to $ <NUM> said in the a percent , , on a nation the said , be he said . .
#
#
# step:  2400 | time: 9.02 | loss: 4.118
# | tgt:  <GO> a tradition of labor day racing was established long ago in the inland empire . <SEP>
# | f_prd:  the technology-laced of the <NUM> , was been <NUM> of , the <NUM> quarter . <SEP>
# | b_prd:  <GO> a one the the saddam , and ( <NUM> <NUM> in the a <NUM> .
#
#
# step:  2480 | time: 8.98 | loss: 3.960
# | tgt:  <GO> justice minister martin cauchon and prime minister jean chretien both have said the government will introduce legislation to decriminalize possession of small amounts of pot . <SEP>
# | f_prd:  the said said said , the the said 't said 't been the governor 's be be to be <NUM> , the county , the . <SEP>
# | b_prd:  <GO> john minister <GO> <quote> the prime minister there <GO> we , said the it to the , to the breach and the breach in said .
#
#
# step:  2560 | time: 8.98 | loss: 3.536
# | tgt:  <GO> the ireland palestine solidarity campaign , of which he was a member , said he was researching a schools exchange project . <SEP>
# | f_prd:  the dow 's 't jones , <quote> the said said not sign of <quote> he is not the statement . . . <SEP>
# | b_prd:  <GO> the ireland palestine the years one , said he , the <NUM> , said he were to for and the said .
#
#
# step:  2640 | time: 8.98 | loss: 3.474
# | tgt:  <GO> a sign outside the peachtree restaurant reads : <quote> pray for eric rudolph . <quote> <SEP>
# | f_prd:  the statement that the first minister is the <quote> we is the the , <SEP> <SEP>
# | b_prd:  is a <quote> of the an be said , <quote> <quote> <quote> <quote> said . .
#
#
# step:  2720 | time: 8.94 | loss: 3.396
# | tgt:  <GO> however , the talk was downplayed by pbl which said it would focus only on smaller purchases that were immediately earnings and cash flow accretive . <SEP>
# | f_prd:  the , the company 's not in the the said the was be in to the years that was not in than a . . . <SEP>
# | b_prd:  <GO> later <GO> the , was <GO> of , , said it to focus based on smaller purchases , was , , and barclay lpga said .
#
#
# step:  2800 | time: 9.65 | loss: 3.220
# | tgt:  <GO> <quote> the matrix reloaded , <quote> which opened in limited previews wednesday night , took in an estimated $ <NUM> million for all five days . <SEP>
# | f_prd:  the we company reloaded , <quote> he said in the of in , , <quote> the the alpharetta the <NUM> million . the $ year . <SEP>
# | b_prd:  <GO> , the matrix reloaded , , reloaded <GO> in limited previews last <NUM> , <NUM> for an to $ <NUM> <NUM> of to <NUM> <NUM> .
#
#
# step:  2880 | time: 9.69 | loss: 3.087
# | tgt:  <GO> <quote> this is an extremely heartrending time for the entire brandeis university community . <SEP>
# | f_prd:  the we , a lot been time to the united name conference . . <SEP>
# | b_prd:  <GO> <GO> there is to an a field in the at a 's said .
#
#
# step:  2960 | time: 9.00 | loss: 3.314
# | tgt:  <GO> rumsfeld , who has been feuding for two years with army leadership , passed over nine active-duty four-star generals . <SEP>
# | f_prd:  the , the said been arrested to the years , the 's , said as the years officer . . <SEP>
# | b_prd:  <GO> capps , , has been <NUM> next two , and new <NUM> , at of on chief sexual said .
#
#
# step:  3040 | time: 8.92 | loss: 2.924
# | tgt:  <GO> <quote> i 'm quite positive about it except i wouldn 't want it to cut across anything now occurring and she accepts that , <quote> he said . <SEP>
# | f_prd:  the we think not know a the , to would 't a to , be with the , , , the said . said <quote> said said . <SEP>
# | b_prd:  <GO> <quote> i 'm quite we if , <quote> we wouldn i send going not , what is being , <quote> he accepts seriously , <quote> he <NUM> .
#
#
# step:  3120 | time: 8.95 | loss: 2.777
# | tgt:  <GO> her detention brings to <NUM> the number of the <NUM> who have been caught . <SEP>
# | f_prd:  the <NUM> is to the percent 1,700-square-mile of the <NUM> million was been killed in <SEP>
# | b_prd:  <GO> the administration brings in on the half on than , may have were <NUM> .
#
#
# step:  3200 | time: 8.90 | loss: 2.823
# | tgt:  <GO> later in the day , however , a former intel executive turned the tables in a speech where he blasted wireless as being too complicated and too difficult to install . <SEP>
# | f_prd:  the in the first , the , the spokesman first , was to tables in the first to the was a with the complicated complicated . the . to be . <SEP>
# | b_prd:  <GO> <GO> in the however <GO> however , neither <GO> the had exactly the pistol in a , where he blasted known of and been wins and for according to said .
#
#
# step:  3280 | time: 8.91 | loss: 2.703
# | tgt:  <GO> at <NUM> , lionel tate was charged with first-degree murder over the death of tiffany eunick . <SEP>
# | f_prd:  the the , <NUM> shanell was <NUM> with the <NUM> and the first of the island , <SEP>
# | b_prd:  <GO> in said , spot , was charged in a , in the outskirts of the said .
#
#
# step:  3360 | time: 8.95 | loss: 2.830
# | tgt:  <GO> in <NUM> , president bush named her to the student loan marketing association , the largest u.s. lender for students . <SEP>
# | f_prd:  the the , the said and a only be first important authority , , said company court states . the . <SEP>
# | b_prd:  <GO> in however <GO> mr. he are gregg to the the american medical <NUM> , the the the justification the <NUM> .
#
#
# step:  3440 | time: 8.89 | loss: 2.596
# | tgt:  <GO> he had been in protective custody since being transferred to souza-baranowski in april , officials said . <SEP>
# | f_prd:  the said been unable the products and the transferred <NUM> <NUM> in the , spurred said . <SEP>
# | b_prd:  <GO> , has kept in protective bombings are be , to feast in <NUM> , he said .
#
#
# step:  3520 | time: 8.81 | loss: 2.150
# | tgt:  <GO> <quote> i am advised that certain allegations of criminal conduct have been interposed against my counsel j. michael boxley , <quote> silver said . <SEP>
# | f_prd:  the we am absolutely that we 're were the president were been interposed . the rights , muris and , <quote> said said . <SEP>
# | b_prd:  <GO> <quote> i am advised with certain because the criminal conduct have been interposed , my spokeswoman , michael defenses , <quote> he said .
#
#
# step:  3600 | time: 8.90 | loss: 2.500
# | tgt:  <GO> the technology-laced nasdaq composite index < .ixic > declined <NUM> points , or <NUM> percent , to <NUM> . <SEP>
# | f_prd:  the dow nasdaq composite index .ixic .ixic > was <NUM> points , or <NUM> percent , to <NUM> . <SEP>
# | b_prd:  <GO> the technology-laced nasdaq composite index < .ixic index down <NUM> points , or <NUM> percent , to <NUM> .
#
#
# step:  3680 | time: 9.09 | loss: 2.243
# | tgt:  <GO> it would be cumbersome for restaurants that serve different meals each day , she said . <SEP>
# | f_prd:  the is be distributed , the and will a ectopic a other . <quote> said . <SEP>
# | b_prd:  said it to for cumbersome and restaurants can at different meals white <NUM> , he said .
#
#
# step:  3760 | time: 8.92 | loss: 2.223
# | tgt:  <GO> people in a van opened fire on a pickup and suv believed to be transporting illegal immigrants , said pinal county sheriff roger vanderpool . <SEP>
# | f_prd:  the in the statement configuration in in the collision and the , to be available available and , <quote> the and sheriff and vanderpool . <SEP>
# | b_prd:  <NUM> <GO> in a van wen <GO> on a , the be need will be and illegal immigrants , said pinal county sheriff roger <NUM> .
#
#
# step:  3840 | time: 8.96 | loss: 2.175
# | tgt:  <GO> but in san francisco , <NUM> percent of men and only <NUM> percent of women washed their hands . <SEP>
# | f_prd:  the the the new , the , of the and the more percent of the washed a debts . <SEP>
# | b_prd:  <GO> <GO> in san francisco , <NUM> percent of <NUM> <GO> , <NUM> families of that in a said .
#
#
# step:  3920 | time: 8.87 | loss: 2.046
# | tgt:  <GO> the national transportation safety board had subpoenaed him , but he initially ignored the order . <SEP>
# | f_prd:  the technology-laced unemployment that works had been a , <quote> he was in the dream of <SEP>
# | b_prd:  <GO> the the the this he have hear said , that who who to to said .
#
#
# step:  4000 | time: 8.91 | loss: 2.179
# | tgt:  <GO> five more human cases of west nile virus , were reported by the mesa county health department on wednesday . <SEP>
# | f_prd:  the months stock students of the school court , and expected by the u.s. county market department . the . <SEP>
# | b_prd:  <GO> <quote> , <NUM> aftermath of the the <NUM> , were fuel of the knox county the el-sheikh on said .
#
#
# step:  4080 | time: 8.86 | loss: 2.226
# | tgt:  <GO> a rival distributor , mike selwyn from united international pictures , says that unlike the matrix revolutions , he cannot detect any advance scepticism , even within the business . <SEP>
# | f_prd:  the <NUM> palestine , who abdullah and the states syndrome , a the akbar the government , , <quote> said detect the night . , <quote> chocolate the spotlight . <SEP>
# | b_prd:  <GO> a rival distributor , mike selwyn with united international pictures , said , and the matrix revolutions that he to reached a police filters , him to 's <NUM> .
#
#
# step:  4160 | time: 8.90 | loss: 1.793
# | tgt:  <GO> moore had no immediate comment tuesday . <SEP>
# | f_prd:  the 's been immediate standard on . <SEP>
# | b_prd:  <GO> , has an for on <NUM> .
#
#
# step:  4240 | time: 8.89 | loss: 2.042
# | tgt:  <GO> after he was led into the execution chamber and strapped to a gurney , swisher raised his head and appeared to smile as the prison chaplain spoke in his ear . <SEP>
# | f_prd:  the the was a by the execution chamber and strapped to the gurney , swisher raised the wife , harassed to smile on the main chaplain spoke in a towel . <SEP>
# | b_prd:  <GO> <GO> he been led of the execution chamber and strapped to a gurney , swisher raised 's head and appeared a smile from the and chaplain dance of bloody said .
#
#
# step:  4320 | time: 8.96 | loss: 2.102
# | tgt:  <GO> cruz came to the united states in <NUM> , a year after fidel castro overthrew a dictatorship and installed a communist government . <SEP>
# | f_prd:  the 's in the united states , the , was communist and fidel castro overthrew a dictatorship and was the communist government . <SEP>
# | b_prd:  <GO> , pointed in the united founded march <NUM> , a , of fidel castro overthrew a dictatorship and , an the said .
#
#
# step:  4400 | time: 8.89 | loss: 1.830
# | tgt:  <GO> in <NUM> , for example , the dow dropped more than <NUM> points , or <NUM> percent , between may and october , due largely to terrorism fears driven by headlines . <SEP>
# | f_prd:  the the , the example , the barometer jones more than <NUM> percent , or <NUM> percent , to the , the , due largely fears fears fears driven by headlines . <SEP>
# | b_prd:  <GO> , <NUM> , for <NUM> , the dow dropped more rose <NUM> points , or <NUM> percent , on <NUM> in <NUM> , , according of terrorism fears driven to said .
#
#
# step:  4480 | time: 8.93 | loss: 1.809
# | tgt:  <GO> mr. bankhead said the crime scenes indicated that the killer was <quote> very methodical . <quote> <SEP>
# | f_prd:  the kiely said the governor scenes indicated that the case had a a methodical . <quote> <SEP>
# | b_prd:  <GO> mr. bankhead said the crime scenes said that the , , and very longhorn . .
#
#
# step:  4560 | time: 8.85 | loss: 1.855
# | tgt:  <GO> <quote> oracle 's offer undervalues the company and is not in the best interest of peoplesoft stockholders , <quote> said peoplesoft president and ceo craig conway , in the statement . <SEP>
# | f_prd:  the i 's daughters undervalues the new , was not asked the first beautiful of the stockholders , <quote> he the president . ceo craig conway , <quote> the statement . <SEP>
# | b_prd:  <GO> <quote> oracle 's <quote> undervalues the ' it was be in the a president of al stockholders , <quote> said vice president and ceo craig conway said in a said .
#
#
# step:  4640 | time: 8.90 | loss: 1.860
# | tgt:  <GO> the document stated : <quote> this report does not attempt to address the complexities of this issue . <quote> <SEP>
# | f_prd:  the dow said , <quote> we blackout was not immediately to the the complexities of the story . <SEP> <SEP>
# | b_prd:  <GO> the spokesman said <GO> <quote> the , did an tried to in the part <quote> climate sin . .
#
#
# step:  4720 | time: 8.92 | loss: 1.344
# | tgt:  <GO> ig farben 's <NUM> properties were valued at around <NUM> million euros ( $ <NUM> million ) and the firm had debts totalling some <NUM> million euros . <SEP>
# | f_prd:  the farben 's <NUM> properties were valued at $ <NUM>-million million euros ( $ <NUM> million in and the firm had debts totalling a <NUM> million euros . <SEP>
# | b_prd:  <GO> ig farben 's <NUM> properties were valued at at <NUM> <NUM> euros to $ <NUM> r300-million , and the and had debts totalling $ <NUM> <NUM> <NUM> .
#
#
# step:  4800 | time: 8.84 | loss: 1.680
# | tgt:  <GO> that ought to be the standard â not how many people sign up , <quote> he said . <SEP>
# | f_prd:  the applies to be the motive , , a the years , that to <quote> he said . <SEP>
# | b_prd:  added that ought to , the it to to how and a being supportive , <quote> he <NUM> .
#
#
# step:  4880 | time: 8.95 | loss: 1.540
# | tgt:  <GO> he added democrats are not going to make progress if we dont broaden the tent . <SEP>
# | f_prd:  the said that that going solely to be progress if they dont broaden the tent . <SEP>
# | b_prd:  <GO> he suu we had are going to make progress if we 't broaden the <NUM> .
#
#
# step:  4960 | time: 8.90 | loss: 1.482
# | tgt:  <GO> the cradle of liberty council isn 't the first one to buck the national group 's stance . <SEP>
# | f_prd:  the company of reckoning management isn 't say first member of buck the government government and bloody . <SEP>
# | b_prd:  <GO> the cradle of liberty funny isn of the for authority to with the the child 's <NUM> .
#
#
# step:  5040 | time: 8.90 | loss: 1.613
# | tgt:  <GO> doctors would face fines and up to two years in prison for performing the procedure , except as a lifesaving step . <SEP>
# | f_prd:  the has be a and reportedly to the years ago prison , the the first , but as a lifesaving african . <SEP>
# | b_prd:  said he would to fines face up to <NUM> years in , in in the <NUM> , theater to a to <NUM> .
#
#
# step:  5120 | time: 8.93 | loss: 1.703
# | tgt:  <GO> tenet has been under scrutiny since november , when former chief executive jeffrey barbakow said the company used aggressive pricing to trigger higher payments for the sickest medicare patients . <SEP>
# | f_prd:  the said said arrested scrutiny on the , but the howard executive , barbakow , the government 's aggressive pricing to have a payments to the sickest <NUM> . . <SEP>
# | b_prd:  <GO> , has <GO> very scrutiny in <NUM> , , and chief executive jeffrey , said the he used aggressive pricing to launched higher niigata for the sickest harassed <NUM> .
#
#
# step:  5200 | time: 9.01 | loss: 1.405
# | tgt:  <GO> winners will be announced in a june <NUM> ceremony broadcast on cbs from radio city music hall . <SEP>
# | f_prd:  the will be distributed in the hospital <NUM> ceremony broadcast of the . radio city music hall . <SEP>
# | b_prd:  <GO> winners will was million in the $ <NUM> ceremony broadcast on ceremonies of radio the music said .
#
#
# step:  5280 | time: 8.92 | loss: 1.373
# | tgt:  <GO> the mariners piled on against randy choate and juan acevedo in the bottom of the inning . <SEP>
# | f_prd:  the technology-laced circuit for the the choate and juan acevedo in the united of the war . <SEP>
# | b_prd:  <GO> the mariners piled forest torched randy choate and juan acevedo in the part of the said .
#
#
# step:  5360 | time: 8.89 | loss: 1.208
# | tgt:  <GO> niels told an interviewer in <NUM> he thought the old man would outlive him by many years . <SEP>
# | f_prd:  the told the interviewer against the , were the number game is outlive him for the years . <SEP>
# | b_prd:  <GO> niels told an interviewer in that he thought the the he would outlive spurred for <NUM> <NUM> .
#
#
# step:  5440 | time: 8.93 | loss: 1.380
# | tgt:  <GO> there was no way the man could hear him , but he turned and mouthed something . <SEP>
# | f_prd:  the was a immediate the nation 's hear him , but he said in mouthed something . <SEP>
# | b_prd:  <GO> there is no way the time could hear him , , who , and mouthed <NUM> .
#
#
# step:  5520 | time: 8.94 | loss: 1.415
# | tgt:  <GO> the top rate will go to <NUM> percent for all residents with taxable incomes above $ <NUM> . <SEP>
# | f_prd:  the technology-laced standard of be for kill percent of the the with taxable <NUM> by <NUM> <NUM> . <SEP>
# | b_prd:  <GO> the californias , to month constitute <NUM> <NUM> of from residents residents taxable incomes to to said .
#
#
# step:  5600 | time: 8.90 | loss: 1.025
# | tgt:  <GO> the blue-chip dow jones industrial average < .dji > slipped <NUM> points , or <NUM> percent , to <NUM> . <SEP>
# | f_prd:  the technology-laced dow jones industrial average .dji .dji > rose <NUM> points , or <NUM> percent , to <NUM> . <SEP>
# | b_prd:  <GO> the the dow jones industrial average < .ixic index down <NUM> points , or <NUM> percent , to <NUM> .
#
#
# step:  5680 | time: 8.91 | loss: 1.176
# | tgt:  <GO> the seventh person charged in the case - habis abdu al saoub - remains at large . <SEP>
# | f_prd:  the company product in with the united , habis abdu al saoub , remains at a . <SEP>
# | b_prd:  <GO> the seventh been failure on the <NUM> of habis abdu al saoub , remains at <NUM> .
#
#
# step:  5760 | time: 8.87 | loss: 1.260
# | tgt:  <GO> uk retail like-for-like sales for the <NUM> weeks to december <NUM> were flat , with gross margin down two percentage points . <SEP>
# | f_prd:  the forces like-for-like stevens last the first percent in the <NUM> , killed , compared gross margin without <NUM> percentage points . <SEP>
# | b_prd:  <GO> <GO> <GO> like-for-like shares at at <NUM> <NUM> in december <NUM> were flat contact its gross margin to <NUM> percentage said .
#
#
# step:  5840 | time: 8.95 | loss: 1.182
# | tgt:  <GO> sars , the deadly respiratory disease first detected in china last november , gave the agency its first real test of a new state-of-the-art emergency operations center . <SEP>
# | f_prd:  the has who deadly respiratory disease , detected in the 's november , including the company chief first real test of the face state-of-the-art emergency operations center . <SEP>
# | b_prd:  <GO> sars , the deadly respiratory disease first detected in china last november , before the for the first real behalf and a new state-of-the-art emergency medical said .
#
#
# step:  5920 | time: 8.87 | loss: 1.334
# | tgt:  <GO> prosecutors said pw marketing violated the <NUM> anti-spam law because these unsolicited e-mails were sent without a free call number for recipients to phone to stop additional mailings . <SEP>
# | f_prd:  the said the marketing violated the rendezvous anti-spam law who of unsolicited e-mails has killed to to building number to of recipients to phone on the additional mailings . <SEP>
# | b_prd:  <GO> prosecutors said pw marketing violated a <NUM> anti-spam law that the unsolicited e-mails were e-mail is a a call number for recipients african <quote> to stop additional said .
#
#
# step:  6000 | time: 8.81 | loss: 1.231
# | tgt:  <GO> more than <NUM> people rallied over three days , proclaiming that genetically modified foods weren 't the answer to the world 's food problems . <SEP>
# | f_prd:  the than <NUM> people staged the the months , proclaiming that genetically modified foods weren 't the answer to the world 's food problems . <SEP>
# | b_prd:  <GO> more than <NUM> people rallied over these talks , proclaiming that genetically modified foods weren to the answer to the president 's the said .
#
#
# step:  6080 | time: 8.89 | loss: 1.070
# | tgt:  <GO> the group will be headed by state department official john s. wolf , who has served in australia , vietnam , greece and pakistan . <SEP>
# | f_prd:  the dow has be regulate by the â for tom s. and , a is served in the , and , greece and pakistan . <SEP>
# | b_prd:  <GO> the it will also headed the justice state said john s. defender , who , <quote> , australia , vietnam , greece and <NUM> .
#
#
# step:  6160 | time: 8.84 | loss: 1.163
# | tgt:  <GO> civilian reservists also could be sent overseas for jobs such as reconstruction in afghanistan and iraq , working in positions from translator to truck driver . <SEP>
# | f_prd:  the reservists also could be sent overseas for jobs such as reconstruction in the and the , <quote> in positions from translator to truck driver . <SEP>
# | b_prd:  <GO> civilian reservists , could be sent overseas for jobs such as reconstruction in afghanistan northern percent , million 's positions from translator subscribers a said .
#
#
# step:  6240 | time: 8.82 | loss: 1.049
# | tgt:  <GO> nearly all of ford 's second-quarter profit came from ford credit , which earned a net $ <NUM> million , up <NUM> percent . <SEP>
# | f_prd:  the <NUM> of the 's second-quarter profit came from ford credit , which earned $ net $ <NUM> million , down <NUM> percent . <SEP>
# | b_prd:  <GO> nearly all of ford 's second-quarter profit budget a ford credit , which earned a to $ <NUM> francs , of <NUM> <NUM> .
#
#
# step:  6320 | time: 8.84 | loss: 1.051
# | tgt:  <GO> state media said there were at least <NUM> dead and over <NUM> injured . <SEP>
# | f_prd:  the secretary said it was not least <NUM> dead and russian <NUM> injured . <SEP>
# | b_prd:  <GO> state media said , killed at least <NUM> dead and and <NUM> <NUM> .
#
#
# step:  6400 | time: 8.98 | loss: 1.029
# | tgt:  <GO> though that slower spending made <NUM> look better , many of the expenditures will actually occur in <NUM> , making that year 's shortfall worse . <SEP>
# | f_prd:  the the slower spending said a look better , the of the expenditures actually be occur in the , <quote> the he 's shortfall worse . <SEP>
# | b_prd:  <GO> though that slower spending made <NUM> look <NUM> , many of the expenditures will will billion $ percent , , the year 's shortfall said .
#
#
# step:  6480 | time: 8.92 | loss: 1.024
# | tgt:  <GO> this change in attitude gave upscale purveyors including neiman marcus group inc. and nordstrom inc . , along with some boutique retailers , strong sales gains in may . <SEP>
# | f_prd:  the palm that attitude monumental upscale purveyors including neiman marcus , and and nordstrom inc . , along with the boutique retailers , and sales gains in monday . <SEP>
# | b_prd:  <GO> this change in attitude gave upscale purveyors including neiman marcus changed , and nordstrom inc . , along with city boutique retailers and strong sales gains in <NUM> .
#
#
# step:  6560 | time: 8.89 | loss: 1.079
# | tgt:  <GO> californias rate was <NUM> percent , down from a revised <NUM> percent in august and also down from the <NUM> percent posted in september <NUM> . <SEP>
# | f_prd:  the rate was <NUM> percent , down from a revised <NUM> percent in august and a down from a <NUM> percent posted in august <NUM> . <SEP>
# | b_prd:  <GO> californias rate revised <NUM> percent , slipped from a revised <NUM> percent in august is , down at the <NUM> percent level by to said .
#
#
# step:  6640 | time: 8.89 | loss: 1.025
# | tgt:  <GO> he said the local organized crime police were investigating a suspect , but he would not confirm if it was the <NUM>-year-old cited by bitdefender . <SEP>
# | f_prd:  the added the case organized crime were are in the suspect in but he would not confirm if it was not only cited by bitdefender . <SEP>
# | b_prd:  <GO> he said the local organized crime police were investigating a killers , that he would not confirm that it as the the cited by said .
#
#
# step:  6720 | time: 8.93 | loss: 0.855
# | tgt:  <GO> the pilot decided to fly to kennedy , which has longer runways than newark airport . <SEP>
# | f_prd:  the dow found into appeal to hammer , and has been runways . newark weapons . <SEP>
# | b_prd:  <GO> the pilot expected to diverted to kennedy , which a not runways the the <NUM> .
#
#
# step:  6800 | time: 8.90 | loss: 0.881
# | tgt:  <GO> the bank of england starts its two-day meeting on wednesday , but was expected to leave british interest rates steady . <SEP>
# | f_prd:  the broader booked england starts the two-day meeting on wednesday , but that expected to leave british interest rates steady . <SEP>
# | b_prd:  <GO> the bank of england starts a a meeting on coach , it is expected to leave british interest rates said .
#
#
# step:  6880 | time: 8.94 | loss: 0.966
# | tgt:  <GO> a prosecutor said investigators were searching his home in muenster in the presence of his wife when news of his death arrived . <SEP>
# | f_prd:  the spokesman said investigators were searching his home in muenster in the presence of his wife when news of his death arrived . <SEP>
# | b_prd:  <GO> a prosecutor <GO> investigators were searching his home in muenster in the presence of his wife when percent of his they said .
#
#
# step:  6960 | time: 8.88 | loss: 0.970
# | tgt:  <GO> the researchers say that the fact the map bug is present in the vast majority of crohns sufferers means it is almost certainly causing the intestinal inflammation . <SEP>
# | f_prd:  the dow found that the fact that man bug is not , the vast majority of crohns sufferers means it is almost certainly causing the intestinal inflammation . <SEP>
# | b_prd:  <GO> the researchers say that the <quote> the map bug is present in the vast majority of crohns sufferers means and is almost certainly causing the intestinal <NUM> .
#
#
# step:  7040 | time: 8.89 | loss: 0.883
# | tgt:  <GO> <quote> as expected , second-quarter sales were weak driven by the combination of declining retail inventories and market-share losses , <quote> said robert a. eckert , chief executive . <SEP>
# | f_prd:  the i the , second-quarter sales were weak driven by the combination of declining retail inventories and market-share losses , <quote> said robert a. eckert , chief executive . <SEP>
# | b_prd:  <GO> <quote> as expected , second-quarter sales were weak driven by the combination of declining retail inventories and market-share losses , <quote> said robert a. eckert 's chief <NUM> .
#
#
# step:  7120 | time: 8.86 | loss: 0.935
# | tgt:  <GO> <quote> [ they ] were defined by dedication and courage , <quote> said the cia 's director george tenet . <SEP>
# | f_prd:  the i they can were defined by dedication and courage , <quote> said the cia 's director can tenet . <SEP>
# | b_prd:  <GO> <quote> [ loan ] were defined by dedication and courage , , said the cia said director george said .
#
#
# step:  7200 | time: 8.86 | loss: 0.861
# | tgt:  <GO> bafin , germany 's chief financial regulator , and the prosecutor 's office were not immediately available for comment . <SEP>
# | f_prd:  the , the 's chief financial regulator , said the prosecutor 's office were not immediately available for comment . <SEP>
# | b_prd:  <GO> bafin , germany 's chief financial regulator , and the prosecutor 's office were not immediately available to <NUM> .
#
#
# step:  7280 | time: 8.90 | loss: 0.820
# | tgt:  <GO> bloodsworth was ultimately cleared with evidence gathered from a semen stain on the victim 's panties . <SEP>
# | f_prd:  the was ultimately cleared with evidence gathered from a semen stain on the victim 's panties . <SEP>
# | b_prd:  <GO> bloodsworth was was cleared with evidence gathered from a semen stain on the victim 's <NUM> .
#
#
# step:  7360 | time: 8.78 | loss: 0.797
# | tgt:  <GO> <quote> it is a benign web where we hope to catch investors and where each of us can advance our enlightened self interest through cooperation with others . <quote> <SEP>
# | f_prd:  the the 's routine leak impact impact we hope here catch investors for the the of the products advance our enlightened self interest through cooperation with the . <quote> <SEP>
# | b_prd:  <GO> <quote> it send a benign web where we hope to catch investors , where because of that can advance our enlightened self weakness through cooperation with employees . .
#
#
# step:  7440 | time: 8.80 | loss: 0.746
# | tgt:  <GO> mccartney has three children - fashion designer stella , <NUM> , mary , <NUM> , and james , <NUM> - by first wife linda . <SEP>
# | f_prd:  the shares been children - fashion designer stella , <NUM> , mary , <NUM> , and james , <NUM> - people <NUM> wife linda . <SEP>
# | b_prd:  <GO> mccartney by three children - fashion designer stella , <NUM> , mary , <NUM> , and james , <NUM> lay the his wife said .
#
#
# step:  7520 | time: 8.82 | loss: 0.918
# | tgt:  <GO> the technology-laced nasdaq composite index < .ixic > added <NUM> points , or <NUM> percent , at <NUM> . <SEP>
# | f_prd:  the technology-laced nasdaq composite index < .ixic > added <NUM> points , or <NUM> percent , to <NUM> . <SEP>
# | b_prd:  <GO> the technology-laced nasdaq composite index < .ixic > slipped <NUM> points , or <NUM> percent , $ <NUM> .
#
#
# step:  7600 | time: 8.88 | loss: 0.829
# | tgt:  <GO> executive recruiters say that finding a seasoned chief merchandising officer will perhaps be the trickiest of all hires because there is such a dearth of good ones . <SEP>
# | f_prd:  the recruiters say that finding a seasoned option merchandising officer is perhaps be the trickiest of the hires because the is almost a dearth of good ones . <SEP>
# | b_prd:  <GO> executive recruiters say that finding a seasoned chief merchandising it will could at the trickiest of all hires claiming and is as a dearth of public said .
#
#
# step:  7680 | time: 8.84 | loss: 0.712
# | tgt:  <GO> one of the commission 's publicly stated goals is to ensure other producers ' server software can work with desktop computers running windows as easily as microsoft 's . <SEP>
# | f_prd:  the of the oregon 's decision stated goals is to ensure the producers ' server software can connect with desktop computers running windows as easily as microsoft 's customer <SEP>
# | b_prd:  <GO> one that the it 's publicly stated goals is to ensure other producers server server software to work to desktop computers running windows as easily as year <NUM> .
#
#
# step:  7760 | time: 8.81 | loss: 0.657
# | tgt:  <GO> gordon stressed that his bill <quote> is a lesson-learned bill and not a reflection on admiral gehman 's handling of the columbia investigation . <quote> <SEP>
# | f_prd:  the stressed that the dangers would atrociously a lesson-learned bill and was a reflection on admiral gehman 's handling of the name investigation . <SEP> <SEP>
# | b_prd:  <GO> gordon stressed <quote> the airline there is a lesson-learned bill and not a reflection on admiral gehman 's handling of the columbia tent . .
#
#
# step:  7840 | time: 8.79 | loss: 0.776
# | tgt:  <GO> indeed , wolfowitz admitted saturday that neither military action nor <quote> large scale bribery <quote> would solve the issue . <SEP>
# | f_prd:  the , the admitted that that he president action nor her an <quote> bribery <quote> of solve the lottery . <quote>
# | b_prd:  <GO> indeed , report admitted wednesday that neither military action a a large <quote> bribery it would solve climate <NUM> .
#
#
# step:  7920 | time: 8.80 | loss: 0.903
# | tgt:  <GO> woori finance is the only large bank remaining to be sold but the government still has large stakes in several other lenders . <SEP>
# | f_prd:  the finance is a only candidate bank remaining more be tested but they united would made been stakes in the other lenders . <SEP>
# | b_prd:  <GO> woori finance <GO> the only large bank remaining to be , that the that company has large stakes in and other <NUM> .
#
#
# step:  8000 | time: 8.85 | loss: 0.853
# | tgt:  <GO> the cia on monday said voice and sound analysts concluded that saddam is probably the speaker on the tape . <SEP>
# | f_prd:  the broader said the , voice and sound analysts concluded that saddam is a the speaker on the tape . <SEP>
# | b_prd:  <GO> the cia on bush said voice said sound analysts concluded that saddam is likely the speaker on the said .
#
#
# step:  8080 | time: 8.75 | loss: 0.904
# | tgt:  <GO> the law does not regulate how much individuals can contribute to their own campaigns , a decided advantage for millionaires such as schwarzenegger and ueberroth . <SEP>
# | f_prd:  the technology-laced does not regulate how much individuals can contribute to the own campaigns , a decided advantage for millionaires such as schwarzenegger and ueberroth . <SEP>
# | b_prd:  <GO> the law does not regulate how much individuals can contribute to their own campaigns , a decided advantage for millionaires months as president and <NUM> .
#
#
# step:  8160 | time: 8.86 | loss: 0.694
# | tgt:  <GO> mitzna and party secretary ophir pines agreed to convene party organizations within <NUM> days to discuss whether new primaries would be held or a temporary leader appointed . <SEP>
# | f_prd:  the and carter minister ophir pines agreed to convene party organizations within <NUM> days to discuss whether a primaries would be held or a temporary leader appointed . <SEP>
# | b_prd:  <GO> mitzna and party secretary ophir pines agreed to convene party bodies within <NUM> days to discuss whether the primaries would be , or a temporary be <NUM> .
#
#
# step:  8240 | time: 8.83 | loss: 0.744
# | tgt:  <GO> the movie opened over the weekend in the number one spot and the companion game has been on sale since late last month . <SEP>
# | f_prd:  the dow opened on the weekend after the second of spot and the companion game has been killed sale since the last month . <SEP>
# | b_prd:  <GO> the movie opened in the weekend in the number one spot and the companion game has been on sale since late last <NUM> .
#
#
# step:  8320 | time: 8.79 | loss: 0.833
# | tgt:  <GO> dotson was taken to chester river hospital center where he stayed overnight . <SEP>
# | f_prd:  the was arrested to chester river hospital center where she was overnight . <SEP>
# | b_prd:  <GO> dotson was taken to chester river hospital , where he hurricane said .
#
#
# step:  8400 | time: 8.83 | loss: 0.781
# | tgt:  <GO> nationwide , severe acute respiratory syndrome has infected more than <NUM> people , about two-thirds of world 's total , and killed <NUM> of them . <SEP>
# | f_prd:  the , the acute respiratory syndrome has infected more than <NUM> people , including two-thirds of the 's total , <NUM> has <NUM> people the . <SEP>
# ...
# | tgt:  <GO> the group will be headed by state department official john s. wolf , who has served in australia , vietnam , greece and pakistan . <SEP>
# | f_prd:  the company will be headed by the department for john s. wolf , who has served in australia , vietnam , greece and pakistan . <SEP>
# | b_prd:  <GO> the who will be headed by state department official john s. wolf , who has served in australia , vietnam , greece and <NUM> .
#
#
# step:  8880 | time: 8.78 | loss: 0.595
# | tgt:  <GO> his coalition also passed some of the world 's most progressive laws in legalizing gay marriage and euthanasia and decriminalizing the personal use of soft drugs . <SEP>
# | f_prd:  the wife also took some of the world 's most progressive laws in legalizing gay marriage and euthanasia and decriminalizing the personal use of soft drugs . <SEP>
# | b_prd:  <GO> his coalition also passed some of the world 's most progressive laws in legalizing gay marriage and euthanasia and decriminalizing the personal use of prescription <NUM> .
#
#
# step:  8960 | time: 8.78 | loss: 0.631
# | tgt:  <GO> he was reported as saying prime minister sir allan kemakeza had made a deal with him to keep his guns while notorious warlord harold keke 's group was armed . <SEP>
# | f_prd:  the said joined by a that minister sir allan kemakeza had made a deal with him to keep his guns while harold warlord harold keke 's group was armed . <SEP>
# | b_prd:  <GO> he was <GO> as claims prime minister sir allan kemakeza had made a deal with him to keep his guns while notorious while harold keke 's group was <NUM> .
#
#
# step:  9040 | time: 8.80 | loss: 0.616
# | tgt:  <GO> those hot , dry santa ana winds and minimal humidity created optimal conditions for raging fires in at least <NUM> places that have already burned nearly <NUM> acres . <SEP>
# | f_prd:  the who , dry santa ana winds and minimal humidity created optimal conditions for raging fires in the least one places , have been burned nearly <NUM> acres . <SEP>
# | b_prd:  <GO> the hot , dry santa ana winds and minimal humidity created optimal conditions for raging fires made at least <NUM> places but have already burned nearly <NUM> said .
#
#
# step:  9120 | time: 8.85 | loss: 0.666
# | tgt:  <GO> <quote> the longer this series goes , the better chance dirk has to play . <quote> <SEP>
# | f_prd:  the i result manager series goes , the bush chance dirk has to play . <quote> <SEP>
# | b_prd:  <GO> <quote> the longer the series goes , the more chance dirk going to welcome . .
#
#
# step:  9200 | time: 8.74 | loss: 0.595
# | tgt:  <GO> <quote> we do not use service members as guinea pigs , <quote> william winkenwerder , assistant secretary of defense for health affairs , told a pentagon briefing . <SEP>
# | f_prd:  the we make not know service members , guinea pigs , <quote> william winkenwerder , assistant secretary of defense for health affairs . said a pentagon briefing . <SEP>
# | b_prd:  <GO> <quote> we do not use service members as guinea pigs , dr. william winkenwerder , assistant secretary of defense for health affairs he told a pentagon said .
#
#
# step:  9280 | time: 8.83 | loss: 0.689
# | tgt:  <GO> <quote> and they will learn the meaning of american justice , <quote> he said to strong and extended applause . <SEP>
# | f_prd:  the i if will learn the meaning of american justice , <quote> we said to the place extended applause . <SEP>
# | b_prd:  <GO> <quote> and they will learn the meaning of american killers , <quote> he is a strong and extended said .
#
#
# step:  9360 | time: 8.92 | loss: 0.543
# | tgt:  <GO> the standard & poor 's retail index < .rlx > was up more than <NUM> percent . <SEP>
# | f_prd:  the technology-laced & poor 's <NUM> index < .rlx > was up more than <NUM> percent . <SEP>
# | b_prd:  <GO> broad standard & poor 's retail index < .rlx index giving to more from <NUM> said .
#
#
# step:  9440 | time: 8.75 | loss: 0.596
# | tgt:  <GO> swedish telecom equipment maker ericsson ( nasdaq : qcom - news - people ) scrambled up $ <NUM> , or almost <NUM> percent , to $ <NUM> . <SEP>
# | f_prd:  the telecom equipment maker ericsson ( nasdaq : qcom - news - people ) scrambled up $ <NUM> , or <NUM> $ percent , to $ <NUM> . <SEP>
# | b_prd:  <GO> swedish telecom equipment maker ericsson ( nyse : qcom - news - people ) scrambled jumped $ <NUM> , or or <NUM> percent , at to <NUM> .
#
#
# step:  9520 | time: 8.83 | loss: 0.619
# | tgt:  <GO> the decision unnerved voting officials who already have been warning they have barely enough time to organize the election . <SEP>
# | f_prd:  the dow came voting officials who already have been warning they have barely enough time to organize the election . <SEP>
# | b_prd:  <GO> the decision unnerved voting officials who already have been warning they have barely enough time to organize presidential <NUM> .
#
#
# step:  9600 | time: 8.84 | loss: 0.594
# | tgt:  <GO> revenue in the most-recent quarter rose <NUM> percent to $ <NUM> billion . <SEP>
# | f_prd:  the rose the most-recent quarter rose <NUM> percent to $ <NUM> billion . <SEP>
# | b_prd:  <GO> revenue in the most-recent quarter rose <NUM> , and $ <NUM> said .
#
#
# step:  9680 | time: 8.80 | loss: 0.558
# | tgt:  <GO> seiu president andrew stern said the unions are <quote> totally comfortable <quote> with dean 's positions . <SEP>
# | f_prd:  the president andrew stern said the unions are <quote> totally comfortable <quote> with dean 's positions . <SEP>
# | b_prd:  <GO> seiu president andrew stern said the unions are <quote> totally comfortable <quote> with dean 's <NUM> .
#
#
# step:  9760 | time: 8.78 | loss: 0.677
# | tgt:  <GO> after that , he plans to have dinner at camp bondsteel with u.s. troops stationed there . <SEP>
# | f_prd:  the mao the he was to have dinner with camp bondsteel with the troops stationed there . <SEP>
# | b_prd:  <GO> <GO> that , he plans to have dinner at camp bondsteel with u.s. troops stationed <NUM> .
#
#
# step:  9840 | time: 8.81 | loss: 0.614
# | tgt:  <GO> complicating the situation , he continued , are companies , like ibm , whose support of linux <quote> has added credibility and an illusion of support and accountability . <quote> <SEP>
# | f_prd:  the the arrests , he continued , <quote> <quote> , like the , <quote> assistant of the <quote> and <quote> credibility and an illusion of support and accountability . <quote> <SEP>
# | b_prd:  <GO> <GO> the situation , he years group the companies , like ibm , whose endorsement san linux <quote> <quote> added credibility and an illusion of support and this . .
#
#
# step:  9920 | time: 8.85 | loss: 0.555
# | tgt:  <GO> when the manager let him in the apartment , brianna was in her mother 's bedroom lying in a baby 's bathtub , covered with a towel and watching cartoons . <SEP>
# | f_prd:  the you manager let him in the apartment , brianna was in her mother 's bedroom lying in a baby 's bathtub , covered with a towel and watching a . <SEP>
# | b_prd:  <GO> when the manager let him in the apartment , brianna was in her mother 's bedroom was in a baby 's bathtub , covered with a towel and watching <NUM> .
# layers shape= (4, 36, 512)
# layers shape= (4, 36, 512)
# layers shape= (4, 36, 512)
# [array([[[-2.0480119e-01, -2.9716575e-01,  3.9264852e-01, ...,
#           1.7531349e-01, -4.4854632e-01,  2.9644093e-01],
#         [-2.4966021e-01,  5.4194551e-02, -3.7966009e-02, ...,
#           5.4121757e-01, -2.6068264e-01, -3.4099606e-01],
#         [-3.2732579e-01, -1.1493367e-01,  1.0098867e-01, ...,
#           3.2174721e-01, -2.7360290e-01, -7.0188329e-02],
#         ...,
#         [-1.1057573e-03,  2.0595302e-05,  8.5785292e-04, ...,
#           1.4520597e-03, -8.1704312e-04, -1.2396653e-03],
#         [-1.1057573e-03,  2.0595302e-05,  8.5785292e-04, ...,
#           1.4520597e-03, -8.1704312e-04, -1.2396653e-03],
#         [-1.1057573e-03,  2.0595302e-05,  8.5785292e-04, ...,
#           1.4520597e-03, -8.1704312e-04, -1.2396653e-03]],
#
#        [[-2.0480119e-01, -2.9716575e-01,  3.9264852e-01, ...,
#          -6.0759872e-02,  2.6172152e-01, -1.9021867e-01],
#         [-5.3698692e-02,  1.4036539e-01, -2.0694762e-01, ...,
#           4.8806944e-01, -8.6054546e-01, -2.6348660e-02],
#         [ 2.5706908e-01,  3.6961940e-01, -4.9365401e-01, ...,
#          -2.5777301e-01,  1.0070239e-01,  3.2371223e-01],
#         ...,
#         [-1.1057573e-03,  2.0595302e-05,  8.5785292e-04, ...,
#           1.4520597e-03, -8.1704312e-04, -1.2396653e-03],
#         [-1.1057573e-03,  2.0595302e-05,  8.5785292e-04, ...,
#           1.4520597e-03, -8.1704312e-04, -1.2396653e-03],
#         [-1.1057573e-03,  2.0595302e-05,  8.5785292e-04, ...,
#           1.4520597e-03, -8.1704312e-04, -1.2396653e-03]],
#
#        [[-2.0480119e-01, -2.9716575e-01,  3.9264852e-01, ...,
#           4.8081225e-01, -5.3507978e-01,  1.4910778e-01],
#         [-1.7118117e-01,  1.8047233e-01, -3.8162056e-01, ...,
#           3.9982328e-01,  1.6592290e-01, -4.2938623e-01],
#         [-4.3173903e-01, -3.4069739e-02,  4.5091733e-02, ...,
#           1.1913991e-01, -5.7442877e-02,  3.9584222e-01],
#         ...,
#         [-1.1057573e-03,  2.0595302e-05,  8.5785292e-04, ...,
#           1.4520597e-03, -8.1704312e-04, -1.2396653e-03],
#         [-1.1057573e-03,  2.0595302e-05,  8.5785292e-04, ...,
#           1.4520597e-03, -8.1704312e-04, -1.2396653e-03],
#         [-1.1057573e-03,  2.0595302e-05,  8.5785292e-04, ...,
#           1.4520597e-03, -8.1704312e-04, -1.2396653e-03]],
#
#        [[-2.0480119e-01, -2.9716575e-01,  3.9264852e-01, ...,
#          -3.5034174e-01, -1.4960474e-03, -3.4703922e-01],
#         [-1.7118117e-01,  1.8047233e-01, -3.8162056e-01, ...,
#           3.6268273e-01, -2.9966861e-01,  4.2687282e-01],
#         [ 3.6921722e-01,  8.1232324e-02, -3.9098859e-02, ...,
#           1.2638316e-01, -1.4587985e-01,  1.9567366e-01],
#         ...,
#         [-2.3197302e-01,  3.5577998e-01, -2.5407815e-01, ...,
#           1.4520597e-03, -8.1704312e-04, -1.2396653e-03],
#         [-1.1057573e-03,  2.0595302e-05,  8.5785292e-04, ...,
#           1.4520597e-03, -8.1704312e-04, -1.2396653e-03],
#         [-1.1057573e-03,  2.0595302e-05,  8.5785292e-04, ...,
#           1.4520597e-03, -8.1704312e-04, -1.2396653e-03]]], dtype=float32), array([[[ 5.3979758e-02,  4.0734159e-03, -7.0384500e-04, ...,
#           6.5556727e-02,  9.3173170e-01, -9.2749643e-01],
#         [ 5.6462342e-01,  2.0528573e-01, -1.1618351e-02, ...,
#           1.3359321e-05,  9.1820527e-03, -9.1851306e-01],
#         [ 7.5096661e-01,  9.6329290e-01, -4.6097338e-02, ...,
#           9.9949908e-01,  7.6139033e-01, -1.7442639e-01],
#         ...,
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[ 5.3979758e-02,  4.0734159e-03, -7.0384500e-04, ...,
#           9.9852365e-01,  9.6148485e-01, -1.4435165e-04],
#         [ 1.4622179e-04,  7.3634136e-01, -6.1446197e-05, ...,
#           9.9999964e-01,  7.6154697e-01, -2.4062663e-04],
#         [ 1.9895294e-01,  1.8692373e-07, -9.8723143e-01, ...,
#           9.9604189e-01, -6.1018938e-01, -5.8957175e-03],
#         ...,
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[ 5.3979758e-02,  4.0734159e-03, -7.0384500e-04, ...,
#           2.3354730e-01,  7.6135176e-01, -1.0152965e-05],
#         [ 9.3094283e-01,  7.4920923e-01, -2.6523194e-01, ...,
#           7.4210125e-06,  2.9925278e-07, -1.3372945e-03],
#         [ 9.8481750e-01,  7.6702893e-01, -9.4612229e-01, ...,
#           1.0000000e+00,  7.6141846e-01, -2.3698367e-05],
#         ...,
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[ 5.3979758e-02,  4.0734159e-03, -7.0384500e-04, ...,
#           3.7490753e-09,  8.7861935e-08, -2.1946498e-03],
#         [ 9.3094283e-01,  7.4920923e-01, -2.6523194e-01, ...,
#           9.9965274e-01,  9.8831683e-01, -6.0064495e-01],
#         [ 9.3856537e-01,  1.0882535e-10, -9.9500734e-01, ...,
#           9.6923374e-02,  8.6984262e-02, -3.3682105e-04],
#         ...,
#         [ 1.4190131e-07,  9.9999666e-01, -5.2801958e-08, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]]], dtype=float32), array([[[ 6.9596345e-10, -2.3419364e-09,  2.0348077e-08, ...,
#          -1.3363619e-09,  1.5131273e-07, -4.0377470e-04],
#         [ 8.5413926e-10, -7.6017761e-01,  9.6381724e-01, ...,
#          -3.4955918e-09,  4.0386487e-03, -5.8808620e-04],
#         [ 1.5217966e-09, -9.5298761e-01,  1.2724082e-01, ...,
#          -1.6516339e-06,  6.7784572e-01, -5.9647748e-04],
#         ...,
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[ 6.9596345e-10, -2.3419364e-09,  2.0348077e-08, ...,
#          -9.9989009e-01,  7.6159859e-01, -1.2051287e-04],
#         [ 6.8643763e-10, -2.2813708e-04,  6.1677951e-02, ...,
#          -2.4018854e-02,  2.2986261e-04, -7.4302463e-04],
#         [ 1.3075617e-10, -7.6127827e-01,  3.6672680e-03, ...,
#          -2.1161849e-02,  7.6159579e-01, -2.0340608e-02],
#         ...,
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[ 6.9596345e-10, -2.3419364e-09,  2.0348077e-08, ...,
#          -7.6215833e-06,  2.3010382e-02, -3.7536382e-05],
#         [ 5.9310260e-08, -7.5965934e-03,  4.8378251e-10, ...,
#          -9.8655277e-01,  7.4448490e-01, -5.9865089e-04],
#         [ 5.9306096e-08, -8.8076053e-09,  1.2556436e-09, ...,
#          -6.3854252e-04,  7.5739825e-01, -6.9053186e-04],
#         ...,
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[ 6.9596345e-10, -2.3419364e-09,  2.0348077e-08, ...,
#          -9.9829739e-01,  2.3440061e-05, -1.2542202e-01],
#         [ 5.9310260e-08, -7.5965934e-03,  4.8378251e-10, ...,
#          -2.3123826e-01,  7.7795959e-10, -5.3957850e-01],
#         [ 5.9310054e-08, -6.0122269e-03,  7.1482450e-01, ...,
#          -9.9830353e-01,  3.6531099e-04, -7.5513613e-01],
#         ...,
#         [ 9.8190796e-01, -9.2502326e-01,  2.0608202e-05, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]]], dtype=float32)]
