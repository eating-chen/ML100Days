# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
source_folder = '/content/drive/My Drive/data/bert_classifier_1/'
destination_folder = '/content/drive/My Drive/data/bert_classifier_1/'

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.4.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.43)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)

# %%
# !pip install torchtext==0.6.0
# Out:
# Requirement already satisfied: torchtext==0.6.0 in /usr/local/lib/python3.7/dist-packages (0.6.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (0.1.95)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (1.19.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (1.8.1+cu101)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext==0.6.0) (4.41.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchtext==0.6.0) (3.7.4.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.6.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.6.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.6.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.6.0) (2020.12.5)

# %%
import pandas as pd
import numpy as np

import torch
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence

from transformers import BertTokenizer, BertForSequenceClassification

# %%
df_train = pd.read_csv(source_folder + 'train.tsv', sep='\t')
df_test = pd.read_csv(source_folder + 'test.tsv', sep='\t')

# %%
train_titles = {row['index']: row['title'] for _, row in df_train.iterrows()}
train_classes = {row['index']: row['class'] for _, row in df_train.iterrows()}

valid_titles = {row['index']: row['title'] for _, row in df_test.iterrows()}
valid_classes = {row['index']: row['class'] for _, row in df_test.iterrows()}

# %%
train_titles
# Out:
# {0: '亞洲杯奪冠賠率：日本、伊朗領銜 中國竟與泰國並列',
#  1: '9輪4球本土射手僅次武磊 黃紫昌要搶最強U23頭銜',
#  2: '如果今年勇士奪冠，下賽季詹姆斯何去何從？',
#  3: '超級替補！科斯塔本賽季替補出場貢獻7次助攻',
#  4: '騎士6天里發生了啥？從首輪搶七到次輪3-0猛龍',
#  5: '如果朗多進入轉會市場，哪些球隊適合他？',
#  6: '詹姆斯G3決殺，你怎麼看？',
#  7: '大魔王帶頭唱歌！火箭這像是打季後賽？爵士神帥這話已提前投降了',
#  8: '馬夏爾要去切爾西？可以商量，不過穆里尼奧的要價是4000萬加威廉',
#  9: '利希施泰納宣佈賽季結束後離隊：我需要新的挑戰',
#  10: '怎麼樣看待大連一方在中超聯賽第九輪取得的賽季首勝？',
#  11: '科勒·卡戴珊與男友TT共進午餐，曾在他懷孕期間偷腥的渣男被原',
#  12: '作為央視體育體育頻道，CCTV5一到週末就直播馬拉松你怎麼看？',
#  13: '如果2018騎士奪冠，詹姆斯這個冠軍的含金量有多大？',
#  14: '昔日中超金靴半場獨造6球虐爆遼足 華夏送走他後悔嗎？',
#  15: 'NBA歷史排名前十都有誰？',
#  16: '你希望利物浦贏得歐冠嗎？巴薩主帥巴爾韋德的回答耐人尋味',
#  17: '絕殺！詹姆斯38+7再創傳奇一刻，兩護法創另類神跡更功不可沒',
#  18: '再現絕殺！今天的老詹怎麼吹',
#  19: '拜仁3比1逆轉科隆，J羅現世界級做餅',
#  20: '白送一個點球！恆大都不要？卡納瓦羅笑容真有意思',
#  21: '劉詩雯戴罪立功取勝平野美宇為中國女乒拿到世乒賽冠軍，怎麼看待這場比賽？',
#  22: '天堂與地獄是有多近？看看比賽最後8秒的猛龍就知道了',
#  23: '魯能隊員的身高',
#  24: 'WKG&M-1世界綜合格鬥賽明星見面會引爆鵬城',
#  25: '如何看待第一詹黑皮爾斯，公開贊美詹姆斯？',
#  26: '粵媒：缺少外援的恆大還是不行',
#  27: '熱刺作死的節奏！連墊底隊都輸，歐冠席位懸了？',
#  28: '德帥談沒球隊面試布茲德里克：出於自私的原因，他在這讓我開心',
#  29: '雙刃劍！山東魯能高中鋒讓人又愛又恨',
#  30: '克洛普：希望凱塔能迅速起到作用，可能會邀請他去基輔',
#  31: '在歐洲是奪歐冠難，還是奪聯賽難？這篇文章將告訴您答案！',
#  32: '斯諾克世錦賽半決賽，馬克-威廉姆斯17-15霍金斯，希金斯和威廉姆斯誰能奪冠？',
#  33: '脂肪肝怎樣最快消失？',
#  34: '韋德的一句bad boy！網友們炸了：個個都是段子手！',
#  35: '中國隊亞洲杯抽到上上簽，為何里皮臉色仍然很凝重？',
#  36: '今日直播龍星戰及女子圍甲 + 星陣讓先9連勝 + 暗渡陳倉',
#  37: '如果勇士今年奪得總冠軍，是不是就算建立了王朝？',
#  38: '橫掃東部第一？這事騎士已經乾過一次！直接把對手打到解體重建！',
#  39: '2018陸家嘴金融城足球聯賽昨天拉開帷幕',
#  40: '絕殺猛龍之夜！詹姆斯5次重摔在地，再心酸也值得了！',
#  41: '哦！中國第114個世界乒乓球冠軍——王楚欽！為中國對加油！',
#  42: '朱婷在女排歐冠半決賽中受傷，這會對瓦基弗產生怎樣的影響，還能夠奪冠嗎？',
#  43: '德國男乒3:2艱難戰勝韓國，挺進決賽會師國乒，中德乒乓大戰勝算大嗎？',
#  44: '詹姆斯現在的絕殺球能力在聯盟中是什麼水準？',
#  45: '淘汰恆大也保不住曼薩諾，保級戰釀1-5慘案，球迷怒吼下課！',
#  46: '曝限薪令最快在夏窗出台 恆大重慶或成最大受害者',
#  47: '58同城中甲：下半場的卓爾惹不起 他們這一數據冠絕聯賽',
#  48: '瑞典世乒賽中國女隊奪冠，如何看待新聞發佈會上石川佳純充當中國翻譯？',
#  49: '世乒賽男團決賽，中國隊3-0完勝德國，兩隊的排兵布陣有哪些亮點和失誤？',
#  50: '道義放兩旁利字擺中間，屢戰屢敗的曼薩諾還能走多遠？',
#  51: '如果騎士今年一輪游，那麼詹姆斯的歷史地位會受影響嗎？他還有機會再進總決賽嗎？',
#  52: '通過運動健身，你覺得對你最大的改變是什麼？',
#  53: '上港主場1-2負於國安，遭遇聯賽兩連敗，上港到底輸在哪？',
#  54: '法網衛冕冠軍在馬德里首輪出局，法網衛冕前景蒙上陰影',
#  55: '騎士和步行者戰成搶七險勝，而猛龍即將被橫掃，步行者跟猛龍的區別在哪裡？',
#  56: '中超單場消息：埃爾克森建功難救主 上港主場遭遇國安逆轉',
#  57: '惠若琪被問女排中素顏誰最美，她機智地回答郎平，你怎麼看？',
#  58: '維亞利：尤文不應該簽埃姆雷-詹，而該選拉基蒂奇',
#  59: '大連一方3:0完勝恆大，足協杯出局、又被一方大敗，恆大怎麼了？',
#  60: '19年亞洲杯國足所在的C組算是上上簽嗎？',
#  61: '安德森數據依舊犀利！對比之後並沒有變化，德安東尼在下一盤大棋',
#  62: '勒布朗已是美國各大媒體公認的歷史第二人，他與喬丹的差距究竟還有多大？',
#  63: '騎士戰勝猛龍拿到賽點，詹姆斯此項數據NBA第一，超過喬丹',
#  64: '凱西談德羅贊：投不好也可以做其它事，比如防守',
#  65: '24+5+4，第一新秀換人！20歲天才刷爆72年歷史，小詹皇被他打爆',
#  66: '人和逼平魯能，京城狂漲粉，北京國安下輪有望登頂！',
#  67: '瓦基弗銀行3:2逆轉意大利冠軍，晉級歐冠決賽，距離全滿貫又近了一步，怎麼看？',
#  68: '中超第九輪，山東魯能0:0戰平北京人和，錯失登頂良機，怎麼評價本場比賽？',
#  69: '為什麼提起火箭隊，很多球迷就會想起奧拉朱旺？',
#  70: '世乒賽奪冠後，劉詩雯調侃自己在職業生涯末端，兩年後奧運會還能見到小棗嗎？',
#  71: '2018年俄羅斯世界杯12座球館巡禮——伏爾加格勒體育場',
#  72: '詹皇絕殺樂福21+16，騎士險勝猛龍總比分3-0，你怎麼看？',
#  73: '聯賽8輪不敗+斬落領頭羊 國安攪亂中超爭冠格局',
#  74: '2019亞洲杯中國國足到底怎樣做才能「奪冠」？',
#  75: '一水二浪三死神 濃眉做花迪做葉 橫批？',
#  76: '傑森-特里：塔特姆打出了超過他年齡的極佳表現',
#  77: '多點開花，國際米蘭客場大勝烏迪內斯',
#  78: '生猛！這個女人當4年馬刺助教，現在又要去應聘主教練！',
#  79: '離被橫掃不遠？猛龍系列賽6困擾難解決：1優勢騎士輕鬆破除',
#  80: '四國青年女籃亞特拉斯賽在秀舉行',
#  81: '史蒂文斯神奇調整凱爾特人加時再勝76人，蘇群：76人完了',
#  82: '大連海那麼多，都有什麼海上遊樂項目？',
#  83: '德羅贊連續13場季後賽面對騎士沒有投進三分',
#  84: '亞洲杯分組國足抽得上上簽，國足就一定能出線嗎？',
#  85: '撒彩紙也不看清楚，打掃了足足七分鐘！凱爾特人竊喜中！',
#  86: '時間過去將近兩年了，大家是如何看待杜蘭特加盟勇士這件事情？',
#  87: '卡拉斯科的底線過人和本澤馬的哪個更優秀？',
#  88: 'NBA如果用帶隊能力給現役球星排名，前五都有誰？',
#  89: '延邊富德怎麼了？主帥樸泰夏怎麼了？',
#  90: '米體：比格利亞將在意大利杯決賽中復出',
#  91: '男乒世乒賽九連冠',
#  92: '郭躍在社交平台上說丁寧，每次輸掉比賽都說受傷，對此你怎麼看？',
#  93: '猛龍主教練跟泰倫盧在這個系列賽的執教水平你怎麼看？',
#  94: '5戰115分，隔扣被犯規還「口出狂言」，球迷：聽這話就有巨星潛質',
#  95: '你們覺得李秋平加盟山東隊的可能性大嗎？',
#  96: '亞洲杯小組賽中國隊賽程出爐：首戰吉爾吉斯斯坦',
#  97: 'cba歷史上最差的小外援是誰？',
#  98: '姚明的「奧運第四問」：盼00後運動員繼續為國旗奮鬥',
#  99: '女排歐冠半決賽，瓦基弗銀行3:2險勝科內利亞諾，你怎麼看？',
#  100: '山東魯能有沒有可能拿到今年的中超冠軍？',
#  101: '世乒賽決賽，劉詩雯2:3不敵伊藤美誠，對此你怎麼看？',
#  102: '為何看到2018NBA季後賽勇士VS鵜鶘G3，勇士球迷稱勇士是在放水？',
#  103: 'WWE巨星究竟多有錢？約翰塞納有私人車庫，比WWE老闆的車還多！',
#  104: '大連一方主場3-0擊敗廣州恆大，取得中超首勝，他們取得勝利的原因是什麼？',
#  105: '為什麼國人能接受並喜歡石川佳純，但不怎麼喜歡張本智和？',
#  106: '日媒：日乒和中國的差距正在縮小',
#  107: '上港1-2輸給國安的比賽中，國安後衛劉歡的手球，沒有判罰點球，是不是誤判？',
#  108: '網傳《馬卡報》披露，內馬爾希望加盟皇馬搭檔C羅，可能性有多大？',
#  109: '德甲官方第33輪最佳陣容：J羅入選 馬里奧-戈麥斯在列',
#  110: '凱西教練：我們這個賽季已經命懸一線',
#  111: '武當掌門游玄德在生活中。比如街鬥對陣泰拳王西提猜，結果會怎樣？',
#  112: '猛龍慘敗騎士真因曝光！兩錯誤讓詹姆斯上演絕殺，這鍋凱西得背！',
#  113: '魯能0-0客平人和，錯失登頂良機',
#  114: '女排國家聯賽已成新人試金石，她若能把握住上位良機必成大器！',
#  115: '如果本賽季詹姆斯率領騎士奪冠，詹姆斯將有怎樣的歷史地位？',
#  116: '這一球之後，來看看各路球星怎麼就變「詹吹」了',
#  117: '爵爺，請你為自己再贏一次！',
#  118: '劉詩雯首負日本因策略不當？8年磨礪自我救贖，劉國梁贊她這一點',
#  119: '詹姆斯38分壓哨拋投絕殺 騎士3-0猛龍拿到賽點',
#  120: '國腳張呈棟：從沒想過自己會出一本書',
#  121: '離開新疆的李秋平，下賽季會到哪個球隊執教？',
#  122: '過人如本澤馬？卡拉斯科點贊後引來馬競球迷指責',
#  123: '中國自己的「球王」：22歲新星戲耍恆大3國腳太強悍！',
#  124: '曼聯傳奇主帥弗格森突發腦溢血入院，現在情況如何？',
#  125: '侯森：給自己定位代班門將，等楊智復出國安會更進一步',
#  126: '易建聯接班人曬邀請函 秀警句激勵自己不忘初心',
#  127: '西蒙斯：我們涼涼了，0-3沒希望了，球迷：你們需要詹姆斯，追吧',
#  128: '丟一場贏一場，今天劉詩雯在世乒賽女團決賽的表現值不值得表揚？',
#  129: '跑馬拉松你是如何準備的，要準備些什麼？',
#  130: 'NBA和CBA差距在哪裡？6張圖一目瞭然！',
#  131: '上港主場1-2負於國安，遭遇聯賽兩連敗，上港到底輸在哪？',
#  132: '騎士VS猛龍G3，樂福在內線強硬一打三，你怎麼看？',
#  133: '競籃2串1：勇士客場擒鵜鶘 爵士主場再負火箭',
#  134: '騎士官宣一消息，詹姆斯做出回應，泰倫盧成最大贏家',
#  135: '皇馬2大鐵主力將無緣國家德比',
#  136: '這支球隊老闆出場踢三場足協杯創歷史，球隊三輪狂丟14球也創紀錄',
#  137: '世界殘疾人射擊錦標賽，河北姑娘破世界紀錄奪冠',
#  138: '武當掌門游玄德在生活中。比如街鬥對陣泰拳王西提猜，結果會怎樣？',
#  139: '世乒賽男團決賽：馬龍樊振東許昕上場，奧恰洛夫受傷德國無奈變陣',
#  140: '如何看待「自由搏擊與傳統武術誰厲害」這樣的問題？',
#  141: '2018瑞典世乒賽男團半決賽，中國隊3-0輕鬆取勝，如何評價三位球員的表現？',
#  142: '2019年亞洲杯分組抽籤揭曉，中國隊首奪亞洲杯的機會真的來了嗎？',
#  143: '這一榜單喬丹也只能屈居第二 現役季後賽得分榜他已無可超越',
#  144: '爭冠關鍵戰，老婦人能否主場擒敵',
#  145: '女排北侖集訓，被寄予厚望的小將李盈瑩正在打磨哪些技術環節？',
#  146: '樂福頻繁一打三稱霸猛龍內線 造就詹姆斯驚世絕殺',
#  147: '網傳《馬卡報》披露，內馬爾希望加盟皇馬搭檔C羅，可能性有多大？',
#  148: '主帥1言恐讓德羅贊開啓暴走？2數據扎心，絕境的他平平無奇！',
#  149: '5.5號比賽恆大金英權解圍踢到球了為什麼裁判給點球？',
#  150: '霸氣！中國男隊9-1擊敗德國 「王者之師」斬獲世乒賽團體九連冠',
#  151: '騎士與猛龍G3，詹姆斯打板絕殺猛龍，這球是什麼水平？',
#  152: '廣州富力外援扎哈維的孩子，球場秀球技，頗有老爸的風采',
#  153: '劉詩雯在世乒賽女團決賽的表現如何？',
#  154: '什麼叫打球要用腦，看看人家隆指導',
#  155: '猛龍主教練跟泰倫盧在這個系列賽的執教水平你怎麼看？',
#  156: '身價僅值300萬美刀卻獲中超1億報價，瑞士巨星嘲諷這點錢太少了！',
#  157: '天賦超越泰森，波蘭猛將只因一大天生缺陷無緣世界拳王',
#  158: '大荔縣朝邑鎮：乘「大馬」東風 展名鎮風采',
#  159: '詹姆斯又雙叒叕絕殺，洛瑞直接懵逼',
#  160: '瑞典世乒賽男團決賽，中國隊面對德國隊，應該派出怎麼樣的陣容？',
#  161: '真急了！詹姆斯與洛瑞發生衝突，三分回應再現死亡之瞪+絕殺比賽',
#  162: '皆大歡喜！國乒女隊奪冠後接受採訪 中肯評價日本女乒發揮',
#  163: '朱婷受傷下場調整，瓦基弗銀行差點被逆轉，朱婷決勝局力輓狂瀾',
#  164: '國家德比來襲！巴薩力爭勝利送別大師，皇馬卻擺出全替補陣容？',
#  165: '中甲最新積分榜：梅縣鐵漢21分鐘連入6球打爆遼寧宏運升至第七',
#  166: '奧尼爾:艾科麥佛鯊VS維韋杜詹霍，誰是更強戰隊？',
#  167: '2019亞洲杯中國國足到底怎樣做才能「奪冠」？',
#  168: '埃梅里：姆巴佩本來想去皇馬或巴薩，但我勸住了他',
#  169: '亞洲杯分組國足抽得上上簽，國足就一定能出線嗎？',
#  170: '拒絕握手海因克斯 萊萬多夫斯基究竟為何？',
#  171: 'NBA最新票價排名！勇士隊第一，火箭隊看了都尷尬',
#  172: 'NBA最弱球隊和CBA最強球隊打比賽，哪個能贏？',
#  173: '德羅巴解密助攻秘訣：我喝了球童的聖水',
#  174: '國足攜手傑尼亞！里皮推選3小將前往羅馬訓練',
#  175: '如何在商業活動中不受人欺騙？',
#  176: '瑞典世乒賽中國女隊3-1日本女隊衛冕，如何看待劉詩雯的表現？',
#  177: '哈登和保羅激烈爭吵，保羅伸手還被哈登打飛，安德森全程看呆，最後相互不理，怎麼看？',
#  178: '維特爾：近幾年萊科寧的狀態被人們曲解了',
#  179: 'NBA的三分誰最厲害？',
#  180: '八年抗詹，何時是頭！明年詹姆斯該對東部球隊進行九年義務教育',
#  181: '北控女足主場惜敗',
#  182: '2018陸家嘴金融城足球聯賽昨天拉開帷幕',
#  183: '騎士再勝猛龍拿到賽場，場邊泰倫盧採訪通過樂福花式盛贊詹姆斯',
#  184: '泰倫-盧：當詹姆斯全力衝刺時，沒人能防得住他',
#  185: '詹姆斯又壓哨絕殺！聯盟第一人毫無爭議？',
#  186: '裕安區平橋鄉助力國際馬拉松賽',
#  187: '世界杯第一戰隊捲土重來！集齊六大巨星強攻大力神杯',
#  188: '奧拉朱旺遠赴鹽湖城為火箭隊加油助威，你如何評價？',
#  189: '火箭被爵士打出9-0反擊，保羅，哈登為此爭吵，從中我們能夠看出什麼？',
#  190: '遭遇3連敗，東部2隊面臨生死一戰！坐擁主場優勢，大帝有望破局？',
#  191: '休斯頓火箭隊哈登和雷霆隊威少，還有金州勇士隊杜蘭特，誰的實力更強？',
#  192: '丟一場贏一場，今天劉詩雯在世乒賽女團決賽的表現值不值得表揚？',
#  193: '勒布朗詹姆斯和騎士如何改變季後賽命運？',
#  194: '「滾球體育APP」北京人和vs山東魯能直播分析和預測推薦',
#  195: '溫格主場能否完美謝幕？來看看博彩公司的意圖！',
#  196: '德羅贊取尷尬數據三節「打卡」 他離「超級巨星」還差得有點遠',
#  197: '這才是老詹一見猛龍就往死裡打的真相，真是讓人拔涼拔涼的！',
#  198: '無兄弟不籃球，勝利並不是所有，身邊有一個好兄弟陪你分擔，足矣',
#  199: '你最喜歡的NBA巨星是誰，討厭的巨星又是誰，為什麼？',
#  200: '球隊開心果！火箭官方曬周琦為塔克唱生日歌視頻：真奇妙',
#  201: '猛龍VS騎士G3，詹姆斯絕殺的那一球，騎士隊為什麼不選擇發前場球？',
#  202: '珍藏版！2018俄羅斯世界杯賽程表，世界杯32強巡禮！',
#  203: '英冠第二支衝超隊：百年名隊重返英超，劉德華舅舅被罵4年終得正名',
#  204: '繼詹皇、King James、老北京之外，詹姆斯又得一個新綽號',
#  205: '官方：里貝里與拜仁續約一年',
#  206: '奧蘭多，安迪爾森，詹姆斯，穆謝奎，誰對大連足球的貢獻更大？',
#  207: '科爾不滿隆多墊腳庫里欲向聯盟投訴隆多，要是萊昂納德聽到這消息會有什麼感覺呢？',
#  208: '恆大到底輸在哪裡？！0:3之後卡帥一番話給出輸球真因！',
#  209: '他是中超唯一一個巴西主力 或成世界杯賽場中超最亮眼的名片',
#  210: '世乒賽女團決賽，世界第一快劉詩雯2:3爆冷輸球。你怎麼看？',
#  211: '定個小目標？巴薩盼保不敗+挫皇馬銳氣 助梅西爭歐洲金靴',
#  212: '老將內內的出場時間驟然增加不少，而安德森跌出輪換，德帥此意為何？',
#  213: '中國收入最高的球星：三度結婚終娶小17歲女友，被譽為足球領袖',
#  214: '太幸福！詹姆斯絕殺之夜兒子前來觀戰！賽後父子倆一動作搞笑極了',
#  215: '隆多疑似墊腳庫里，勇士或向聯盟討說法，科爾：那是很危險的動作',
#  216: '籃球正負值是什麼意思？',
#  217: '男團決賽，中德男乒大戰，馬龍兵不血刃3:0贏波爾，為國乒拿到開門紅，如何看待？',
#  218: '誰能娶她？29歲美女奧運冠軍何雯娜重回體壇，想找長腿有腹肌男友',
#  219: '火箭與爵士的第3戰 火箭的輪轉發生了變化 這變化將改變一人命運',
#  220: '尤納斯下賽季會留在廣東嗎？這兩人或許比他更合適，朱總會選誰？',
#  221: '金州勇士、皇家馬德里，誰在世界上影響力大？',
#  222: '如果世乒賽第四局中，劉詩雯不是碰到也同樣輸一局的平野美宇，結局會怎樣？',
#  223: '雖然中國女乒軍團世乒賽3:1戰勝日本，但日本球迷說不久日本女乒會贏中國，你怎麼看？',
#  224: '萊萬與海因克斯決裂，拜仁還有必要留下他嗎？',
#  225: '58同城中甲：替補登場顯神功，黃希揚一展皮爾洛神跡',
#  226: '埃梅里：全隊在幫內馬爾適應巴黎',
#  227: '您也辛苦了！泰倫-盧新聞發佈會上大口飲水',
#  228: '曼城主帥瓜迪奧拉確認亞亞·圖雷今夏離開球隊',
#  229: '亞洲杯分組國足抽得上上簽，國足就一定能出線嗎？',
#  230: '科比他的一生之敵只有一個人，不是詹姆斯，那會是誰？',
#  231: '2018世界杯有哪些強隊缺席？',
#  232: '滎經縣安靖小學開展春季田徑運動會',
#  233: '厲害了！武漢一高校學子在2018華中區學生跆拳道比賽中奪得14金！',
#  234: 'G3，76人最後時刻瘋狂慶祝，為什麼反而輸球了？',
#  235: '勇士全神貫注 2017-2018NBA 勇士VS鵜鶘',
#  236: '洛瑞纏著詹姆斯，導致詹姆斯倒地差點兒引發衝突，為何要吹詹姆斯犯規？你怎麼看？',
#  237: '如果劉國梁出國執教你是支持還是反對？',
#  238: '暫停期間隆多親身向濃眉哥示範如何在內線單打，隊友們看著不說話直點頭，你怎麼看？',
#  239: '發誓加入中國國籍的黑人拳王阿迪薩亞為什麼離開中國了？',
#  240: '足球茶館：作為國米球迷你都知道嗎？',
#  241: '世乒賽1/4決賽馬龍和許昕均取勝，為樊振東鋪平道路，你如何看待？',
#  242: '大連一方主場3-0擊敗廣州恆大，取得中超首勝，他們取得勝利的原因是什麼？',
#  243: '瑞典世乒賽中國女隊奪冠，如何看待新聞發佈會上石川佳純充當中國翻譯？',
#  244: '被打服！騎士詹皇外一人讓球迷心寬了，騎士凱爾特人宿敵再見？',
#  245: '詹姆斯8秒絕殺猛龍，洛瑞表情呆滯含有淚花，你怎麼看？',
#  246: 'NBA球隊是否真的有」相生相克」？',
#  247: '高山滑雪危險嗎？怎麼看經常有人摔出賽道？',
#  248: '如何看待「自由搏擊與傳統武術誰厲害」這樣的問題？',
#  249: '猛龍為什麼又輸了？',
#  250: '為什麼說釣魚窮三代？',
#  251: '意甲第36輪 切沃2:1力克克羅托內 收穫勝利',
#  252: '詹姆斯G3絕殺猛龍，最後時刻追上騎士，猛龍心理有陰影嗎？',
#  253: '世乒賽決賽劉詩雯痛失2賽點，遭伊藤美誠逆轉。究竟是哪裡出問題了？',
#  254: '師徒之爭 舒斯特爾給卡納瓦羅上了一課',
#  255: '今年東決如果騎士打凱爾特人，怎麼樣？',
#  256: '昔日女乒主帥施之皓，最近情況怎麼樣啊？',
#  257: '25球！國家德比的頭號射手——梅西',
#  258: '為什麼女子網球服下裝是裙子？',
#  259: '詹姆斯再次絕殺，3-0領先猛龍，你怎麼看？',
#  260: '「賽事預測」萊加內斯 VS 萊萬特',
#  261: '穆里尼奧希望桑德羅來代替盧克肖在曼聯的位置',
#  262: '不要命了？生死邊緣還敢送溫暖！熱刺托大後果嚴重',
#  263: '瑞典世乒賽中國女隊奪冠，如何看待新聞發佈會上石川佳純充當中國翻譯？',
#  264: '周琦為塔克唱生日歌，全隊被逗的哈哈大笑，你怎麼評價？',
#  265: '請許老闆打開支票本為恆大引入球員，有些人留著真沒什麼用！',
#  266: '瓦基弗銀行3比2擊敗科內利亞諾殺進歐冠決賽，朱婷受傷仍砍24分，你如何評價？',
#  267: '季後賽如此表現的保羅值得火箭續約嗎？',
#  268: '曾以為他墮落平庸了，其實一直在蘊藏中，這就是我們最愛的隆多！',
#  269: '《賞月夜·瞻世界》（第3期）-潘帕斯雄鷹盤旋天際只為最後一擊？',
#  270: '如何看待恆大0:3輸給副班長大連一方，是故意的嗎？',
#  271: '膜拜！詹姆斯絕殺，全聯盟眾球員發推：歷史最佳',
#  272: 'NBA季賽後，東西部半決賽局勢不同，詹姆斯有望再破紀錄',
#  273: '上海上港輸球，山東魯能有機會贏球超越上港排名中超第一嗎？',
#  274: '浙體產業週刊｜浙體產業一周資訊速遞2018-010',
#  275: '全國籃球青訓看山東，濟南體校成冠軍搖籃',
#  276: '《灌籃高手》全國大賽圖文解說（四）',
#  277: '中超第9輪最佳陣容：大連一方成大戶 四大U23搶鏡中超',
#  278: '世乒賽男團冠軍即將產生，國乒男隊能實現史無前例的九連冠霸業嗎？',
#  279: '足球比賽中守門員什麼情況下可以用手，什麼時候又不能？',
#  280: '無懼流言再創記錄，探花：我們的任務是盡快送他們去「見上帝！」',
#  281: '2018-5-6 切爾西 vs 利物浦，今天繼續一場穩膽英超衝擊4連紅',
#  282: '中國隊亞洲杯抽到上上簽，為何里皮臉色仍然很凝重？',
#  283: '馬內：利物浦需要費基爾，他來了將火力全開',
#  284: '馬刺助教梅西納將在今日面試雄鹿主帥職位',
#  285: '老魚絕殺：爵士陷困境無調整餘地，主場戰火箭也無優勢',
#  286: '連續第三次在世乒賽會師決賽，日本女隊都只拿到銀牌',
#  287: '世乒賽女團決賽，世界第一快劉詩雯2:3爆冷輸球。你怎麼看？',
#  288: '周琦為塔克唱生日歌，全隊被逗的哈哈大笑，你怎麼評價？',
#  289: '連續5場20+，綠軍20歲新秀超越伯德，如此數據不輸米切爾西蒙斯',
#  290: '新疆王朝隕落？李秋平卸任主帥，3危機令新疆難爭冠',
#  291: '權健是做什麼的，為什麼那麼有錢？',
#  292: '悲劇又要重演，猛龍連續三場失誤上雙，詹姆斯超帕克成現役第一',
#  293: '詹姆斯現在的絕殺球能力在聯盟中是什麼水準？',
#  294: '下一個世界前十竟然是他？打敗雅桑克萊和考的人說先過我這關',
#  295: '中超第9輪，國安對上港，比賽最後階段裁判的判罰引發爭議，你認為判罰是否存在問題？',
#  296: '為什麼歐冠決賽沒有國內媒體去現場解說，成本很高嗎？',
#  297: '中超聯賽第9輪，重慶斯威0-1天津權健',
#  298: '劉偉解說乒乓球比賽的水平如何？',
#  299: '亨德森：榮幸為克洛普效力，皇馬是強大的隊伍',
#  300: '法治聚焦｜多部門聯合發文規範民間借貸，嚴厲打擊暴力催收',
#  301: '中國最獨特的公司，溫氏究竟厲害在哪裡？',
#  302: '投P2P本金加12%利息全打水漂 後來我開始研究貸款',
#  303: '5月31號前，企業需完成匯算清繳工作，會計注意這5個細節問題',
#  304: '下週一（5.7日）手上持有這些股的要小心',
#  305: '5萬元資金，該做什麼行業？',
#  306: '信用卡賬單免息期與最長50天免息還款技巧大全！',
#  307: '美增加關稅，為何人民幣不降反升？',
#  308: '馮天睿：5.6千三大關何以告破 黃金原油下週一操作建議',
#  309: '報名｜界面資本論壇熱點前瞻：各界共議「創造可持續價值」',
#  310: '2017年的巴菲特股東大會有哪些看點？',
#  311: '巴菲特：美國人生活會越來越好 比洛克菲勒都要過得好',
#  312: '踐行「軍民融合」，助力「一帶一路」',
#  313: '重磅：「5050」計劃打造全國人才生態最優區 「國際濱」蓄勢待發',
#  314: '不僅首季業績持續高增長，這些股中期業績仍可期',
#  315: '目前有35萬存款，怎樣在短期之內翻倍？',
#  316: '中興通訊：關於重大事項進展公告',
#  317: '好好把握比特幣的調整 每次都是機會',
#  318: '尋找地產界「最強大腦」——中國房企2018年度CFO評選啓幕',
#  319: '獨角獸藥明康德週二上市，但一季報淨利已現業績下滑',
#  320: '車子安裝了高速etc，並且綁定的是中行信用卡。現在車準備賣了，etc怎樣處置？',
#  321: '股東代表訴訟應定額收取訴訟費',
#  322: '餘額寶有可能發行自己的銀聯卡，建自己的取款機嗎？',
#  323: '擺地攤小本生意賣什麼最賺錢，那種銷售模式適合你',
#  324: '股票，期貨配資有沒有市場前景？',
#  325: '重磅：漲停板復盤！',
#  326: '目前有35萬存款，怎樣在短期之內翻倍？',
#  327: '4月CPI、進出口等數據將公佈，這些投資機會最靠譜',
#  328: '中國排在前600的姓都有哪些？',
#  329: '大麻竟被做成了衣服',
#  330: '新政策新趨勢，解讀企業的上市背後的門道',
#  331: '兩個人投資開店其中一個人不管，利潤該怎麼分？',
#  332: '巴菲特，一生成功投資的最大秘密',
#  333: '信用卡代還業興起，眾多平台被爆存違規套現、亂收費等問題',
#  334: '比特幣BTC和比特幣現金BCH同時上漲，兩者是否互相影響？',
#  335: '軍工行業11個世界500強大型企業集團資料整理',
#  336: '如何判斷熱點題材板塊的持續性？',
#  337: '很多散戶資金量不多，卻同時持有四五個，甚至十幾個品種的股票，這樣真的好麼？',
#  338: '現在手裡面有兩萬塊錢的閒錢，不是很多。這筆錢怎麼在一年時間內賺最多的錢？',
#  339: '用超過1億元的資金回購公司股份，這3家公司是怎麼了？',
#  340: '聯想五大優勢構建直面萬億市場的新業務模式SIoT',
#  341: '宋清輝：資管新規出爐意味著打破剛性兌付',
#  342: '上證指數持續圍繞3100點震蕩，是築底還是持續下跌？',
#  343: '股票書籍分享——技術分析之五檔買賣盤，還要練習盤感',
#  344: '以茅台酒現在的價格，你認為它還是用來喝的嗎？',
#  345: '幣圈事件：密貨幣是否成為證券，5月7號見分曉，後市操作見下文',
#  346: '如何才能享受8%的定存利率？',
#  347: '萬孚生物：科金控股計劃3個月內減持1%股份',
#  348: '藍星生財之道公眾號增長計劃0.2版本',
#  349: '連續29個跌停刷新A股記錄的ST保千里打開跌停，可否抄底？',
#  350: '投資期限對資產配置的影響',
#  351: '向初梵；5.6週一黃金操作建議，下周黃金走勢分析',
#  352: '網貸逾期後，既不催收也聯繫不到客服，卻遭遇一天200元催收費',
#  353: '三無人員申卡難，掌握申卡技巧快速下卡！',
#  354: '有點閒錢了 放在哪裡收益最划算',
#  355: '新手應該如何系統學習投資？',
#  356: '巴菲特：不太可能向其股東發放一次性特別股息',
#  357: '煙台企業參加廣交會入賬1.23億美元',
#  358: '「上幣公告」ABCC上線DASH、OMG',
#  359: '深市今日停復牌一覽(5月7日）',
#  360: '廣交會到會採購商與成交額實現雙增長',
#  361: '職業操盤手不可外傳的成交量買賣精髓，字字珠璣！',
#  362: '活動預告l 資管新規解讀暨債市投資策略會',
#  363: '餘額寶升級後，有兩只新的貨幣基金，分別是博時基金和中歐基金管理，對用戶有什麼風險嗎？',
#  364: '創業者應該掌握的創業理念和方法',
#  365: '陳柯楓：5.6黃金將繼續反彈，下周操作策略',
#  366: '「擒龍術」核心——抓龍頭讓你不錯過題材或者板塊龍頭的任何機會',
#  367: '信用卡逾期，已還本金10萬，銀行還要催收15萬逾期利息怎麼辦？',
#  368: 'GuruFocus創始人：股神接班人是今年最大亮點',
#  369: '普通外匯投資者該如何炒外匯？',
#  370: '5月6日股市內參',
#  371: '長線投資一般投資什麼股票？',
#  372: '山西首富是個初中生，第二名和第三名的財富加起來也沒首富一半多',
#  373: '是走還是留？15.60元的成本，只怕是無影腳的票，第二天高開出貨',
#  374: '被大多數人忽略的買房好處，我猜你沒有想到！',
#  375: '準備賣大米，麵粉，油，應該在哪裡進貨？',
#  376: '「國六」即將實施，常用的「國三」「國四」會怎樣處理呢？',
#  377: '黃金原油下周走勢分析',
#  378: '一斤兩塊五的青菜人都買的吃，為什麼兩塊五的股票沒人買呢？',
#  379: '上證指數目前已形成2次的超大單資金的底背離了，已有條件見底了',
#  380: '為什麼《英雄聯盟》國服皮膚賣那麼貴？',
#  381: '交通銀行東方航空信用卡申請難嗎？白金卡比較難入手',
#  382: '環保中小企業享受減稅利好，環保裝備製造企業同步起飛',
#  383: '力帆股份再啓定增 擬募資24億元投新能源汽車產業鏈',
#  384: '震蕩行情和單邊行情如何區分？',
#  385: '宿城舉辦現代服務業招商推介會 28個項目成功簽約',
#  386: '龔方雄：BAT回歸將加速中國資本市場的機構化和國際化',
#  387: '普通外匯投資者該如何炒外匯？',
#  388: '宋鴻兵的《貨幣戰爭》這本書可信度有多高？',
#  389: '兩市晚間公告一覽：一公司24.8億投新能源汽車！股民：這夠嗎',
#  390: '黃金周評：非農意外利多黃金維持震蕩，多頭髮力上方阻力重重',
#  391: '深度好文：中國製造業需要擺脫三個陷阱',
#  392: '關於均線系統，有什麼獨特的、有效的見解跟設置用法嗎？',
#  393: '關於配額、新疆棉紡等話題，中棉行協第五屆六次常務理事會作熱議',
#  394: '上交所高層變動！總經理黃紅元將升任理事長',
#  395: '銘碩言5.6黃金非農急催拉盤空單掃尾，虧損該怎麼對待後市',
#  396: '位置很差的水果店，如何通過一招將生意做成社區內最好？',
#  397: '保險關聯交易監管法11年後大修 比現行規定有松有緊',
#  398: '證金公司逆市增持券商股 中小盤成長股逐漸被資金錨定',
#  399: '2018年A股百億富豪：何享健成首富 賈躍亭退出榜單',
#  400: '白馬藍籌股的價格突然下跌，原因有哪些？',
#  401: '中國股市的「莊家」到底是誰',
#  402: '龍頭慘遭砸盤透重大暗示 下周初變盤風暴或驟然來襲？',
#  403: '公告精選：藥明康德將於5月8日上市；南山控股換股吸收合併深基地B',
#  404: '這類股你敢買嗎？',
#  405: '海富通FOF鍍金未果 倉促建倉擇時失敗業績陷泥潭',
#  406: '最近股票虧了4萬多，本金只有10萬，還有必要堅持嗎？',
#  407: '自3月23日以來，A股持續在3100點附近震蕩，股市何時能突破該區域？',
#  408: '幣圈重磅：BTC牛市已來，教你如何把握抄底時機！',
#  409: '中國中藥協會靈芝專業委員會成立大會',
#  410: '增值稅下調後，小規模納稅人開票如何處理？',
#  411: '今日消息面：BCH上漲近3倍，高曉松稱數字貨幣可理解為地下黃金',
#  412: '紫鑫藥業董事長郭春林：三大業務為核心 迎接大健康時代來臨',
#  413: '全國人民喜迎油價上漲！',
#  414: '如果你已然衣食無憂，有200萬閒錢做投資，你會如何使用？',
#  415: '你還在為企業和項目的資金而發愁嘛？你會融資嘛？懂得如何融資嘛',
#  416: '餘額寶升級以後，預期收益率是否會回到6%？',
#  417: '餘額寶升級了，有什麼不一樣？',
#  418: 'Brian Kelly：比特幣在短期內將繼續激增的三個原因',
#  419: '新妖出世，坐等加冕',
#  420: '持有的股票一直不賣能等到牛市大漲嗎，什麼時候才能牛市大漲？',
#  421: '5月5日美股低開高走，大漲將近400個點，對下週一A股走勢有什麼影響？',
#  422: '盤點全國環保行業最賺錢上市公司50強排行榜',
#  423: '「股神」巴菲特被一個8歲女孩問倒了！甚至懷疑自己買錯股票',
#  424: '馬克思的影響從未離開——法國再掀馬克思主義研究熱潮',
#  425: '欠錢不還的人是什麼心態？有錢也不願意還是什麼心態？',
#  426: '450億！又一500強民企跨了 釋放哪些信號',
#  427: '「移動醫療第一股」平安好醫生港交所掛牌上市，融資11億美元',
#  428: '提供借款後立即要求支付利息屬於 變相預先扣除利息',
#  429: '下周核心股票池：世界杯要來，最強最火的居然是只鴨脖概念股',
#  430: '信用卡如何養卡，如何提額快？',
#  431: '現在股市都是2―3元的很多，有哪些可以長期持有？',
#  432: '去香港買保險有何利弊？',
#  433: '真相驚人！白馬股閃崩頻現 到底是賺錢機會還是割韭菜陷阱？',
#  434: '美4月就業數據欠佳 國內經濟短期承壓',
#  435: '江蘇開通首條國際郵輪航線',
#  436: '安永：全球並購交易勢頭正旺不受風險影響 中國為首選五大投資目的地之一',
#  437: '買了這只股票讓巴菲特賺了七倍，而散戶卻至今還在深套之中',
#  438: '技術丨脫硫石膏在水泥生產使用中的幾點措施',
#  439: '股東大會上，巴菲特還提到了減稅、通貨膨脹、報業轉型',
#  440: '股神巴菲特也看多A股？',
#  441: '50歲了，一直是電商方面自由職業者，現在準備職業炒股從哪裡入手？',
#  442: '招行呼和浩特分行感動服務添新舉措',
#  443: '北京餐飲行業用工供、需居高 難堵用工缺口',
#  444: '商標轉讓和商標變更一樣嗎？不一樣嗎？',
#  445: '研究稱2035年廣東GDP將超英法 人均近20萬元',
#  446: '關於中國的投資機會、中美貿易 巴菲特在股東大會上是這樣說的',
#  447: '週一大盤機會難得不突破就創新低',
#  448: '如果一沒有資金二沒有技術，但是有創業的激情，應該如何創業？',
#  449: '新聞簡報：8.7億！阿里首次公佈支付寶們全球活躍用戶數量',
#  450: '中國股市常被股民罵，為什麼？',
#  451: '全自動炒幣機器人CCR炒幣軟件原理介紹',
#  452: '三百溫商共同發起，為溫州企業家量身打造 「慧商大學」正式掛牌',
#  453: '額度這麼低，信用卡怎麼提到10萬呢',
#  454: '股票增發和股票回購是正好相反的兩種操作嗎？',
#  455: '05月06日潛江天氣預報',
#  456: '李謹詺：週一該如何佈局，5.7黃金不破1318短期震蕩下行為主',
#  457: '都說80年下海、90年炒股、00年炒房、10年炒比特幣，那麼現在該乾些什麼？',
#  458: '建築工程中同一項目，母公司投標，子公司能否投標？',
#  459: '大智慧燒14億給李大霄羅傑斯做直播，結果虧17億要退市了，這是誰的鍋？',
#  460: '碧生源(00926)預計2018年上半年收入大幅下降 預虧2000萬-3000萬元',
#  461: '合陽縣未來有什麼發展？',
#  462: '方法論｜大小盤基金組合再探：中美兩國股市的組合變通比較',
#  463: '芝麻信用是怎麼計算出來的？',
#  464: '最新爆文｜存銀行20萬一年後虧了500，必須看看是怎麼回事……',
#  465: '止損真的有必要嗎，止損真的有用嗎，只有1種情況才需要止損！',
#  466: '巴菲特股東大會上的珠寶店、傢具店、牛排館和乒乓球賽',
#  467: '錢程：如何認識K線反轉形態並成功抓頂抄底',
#  468: '妖股第二次砸盤，歡樂海岸還會來反包嗎？',
#  469: '華峰股份：3月內不再籌劃除購買華創股權之外重大事項',
#  470: '分紅後要除權，股價相應下降，股東也沒多賺到錢，意義是什麼？',
#  471: '期貨交易到底難在哪裡？',
#  472: '紙質水瓶面世了，塑料瓶子在飲料包裝市場的命運將如何？',
#  473: '零售企業開發自有品牌的三大痛點',
#  474: '一個創業成功的項目，是這樣做的',
#  475: '如何應對加密貨幣的崩潰？',
#  476: '中金e配股票配資是實盤操作嗎？',
#  477: '分紅險、萬能險、投連險有什麼區別？',
#  478: '為何有的人信用卡能做到快速提額？因為是這個原因',
#  479: '18年大蒜的市場行情怎麼樣，價格有沒有可能提高？',
#  480: '關於均線系統，有什麼獨特的、有效的見解跟設置用法嗎？',
#  481: '股票增發和股票回購是正好相反的兩種操作嗎？',
#  482: '假設一隻股票開盤誰都不買，那是不是只要在漲停板掛一手買單，就能漲停？',
#  483: '如何系統地學習股市？',
#  484: '股市究竟應該如何去學？',
#  485: '「國六」即將實施，常用的「國三」「國四」會怎樣處理呢？',
#  486: '買了太平人壽保險，得了病花了20萬，保險公司說沒有動大手術拒賠怎麼辦？',
#  487: '6月30號後取消第三方支付直接扣賬，支付寶還能直接用於支付嗎？',
#  488: '存100萬賺利息，就可以不上班了嗎？想得太美',
#  489: '一個故事看懂金融危機時錢都去哪裡了？',
#  490: '如果把500萬人民幣存進銀行，光靠利息能過上什麼樣的日子？',
#  491: '如何判斷一個人是聰明還是笨？',
#  492: '十五萬存銀行 每年多少錢 算一下！',
#  493: '行長很著急：浦發銀行成唯一利潤負增長銀行，造假竟造出零不良率',
#  494: '房企和炒房客「復盤無望」降價拋售將加快「房價下跌」',
#  495: '社保不想續交了，已經交的錢能不能退？',
#  496: '「早參」姚振華勝利大逃亡',
#  497: '揭密1990年日本大股災房、地產泡沫真面目',
#  498: '騙子不夠多，傻子永遠都夠用',
#  499: '為什麼很多在工廠上班的人，甘願每月拿著幾千元的固定工資？',
#  500: '如果美國將國債一次性還清，會發生什麼事！',
#  501: '銀行卡沒有錢，如果一直不用，每年都扣年費等等費用，十年二十年後，銀行會主動來要費用嗎？',
#  502: '得寸進尺！沙特石油還漲！中國霸氣拒買，沙特怕了：我是被逼的！',
#  503: '原料上漲疊加需求轉旺 紙價開啓新一輪上漲',
#  504: '產業上下游面對面 服裝定制商走訪柯橋本土面料企業',
#  505: '「不差錢」的上市公司卻偏愛理財 這說明瞭什麼問題？',
#  506: '在騰訊和阿里剛上市時分別購買100股它們的股票，現在將獲利多少倍？',
#  507: '企業家之殤 上市公司董事長選擇自殺真相！',
#  508: '準備職業炒股該從哪裡入手？',
#  509: '中國芯片第一龍頭，橫盤2年底部現金叉，5月或超京東方A',
#  510: '重大利好：通策醫療突發重磅信號，下周抄底最佳時機出現！',
#  511: '合伙開店如何轉讓股份？',
#  512: 'PPP模式聚焦旅遊重點領域 社會資本需有更高要求',
#  513: '在加拿大生活，消費如何？',
#  514: '出欄一頭豬虧損300元，究竟誰能笑到最後！',
#  515: '招行、工行、農行、建行和中行五行的信用卡哪個最好用？',
#  516: '銀行卡沒有錢，如果一直不用，每年都扣年費等等費用，十年二十年後，銀行會主動來要費用嗎？',
#  517: '巴菲特股東大會：關於中國，巴菲特、芒格說了這些',
#  518: '這真的是一場屠殺，剛剛這個國家崩盤了',
#  519: '為什麼是羅森便利店佔領了上海的市場，而不是711？',
#  520: '九年首次！伯克希爾一季度虧損，巴菲特卻靠蘋果派息大賺一筆！',
#  521: '讓青春與奮鬥同行——海南創業創新青年掠影',
#  522: '我在現場：與巴菲特一起尋找下一片投資的熱土',
#  523: '辦信用卡多久可以換工作單位？',
#  524: '小牛之後，EOS會不會倒下？',
#  525: '本金120萬，融資60萬，總資金180萬，專職炒股怎麼樣？',
#  526: '保險的起源與大航海時代',
#  527: '如何快速捕捉翻倍牛股，有沒有什麼技巧？',
#  528: '合伙開店如何轉讓股份？',
#  529: '10個信用卡逾期46萬，但每月多多少少都在還，會被報警抓嗎？',
#  530: '蘋果或率先破萬億美元？蘋果打響反擊戰 五天暴漲600億美元',
#  531: '黑龍江最富有的三大家族，首富是陝西人，排名第三的他是黑龍江人',
#  532: '市場比較認可兩本理論，《波浪理論》《纏中說纏》大家對這兩本理論有什麼深入的見解？',
#  533: '深圳證監局「揮刀」私募新三板 重拳出擊違法違規',
#  534: '怎麼升級餘額寶？',
#  535: '第五人格哪個監管者好？',
#  536: '信用卡如何把臨時額度提升到永久額度？',
#  537: '如何5分鐘獲取3W元以上額度的信用卡技巧？',
#  538: '做中國巴菲特系列之 漲停板環境研究（私募內幕）',
#  539: 'A股納入MSCI倒計時 利好四大板塊',
#  540: '一斤兩塊五的青菜人都買的吃，為什麼兩塊五的股票沒人買呢？',
#  541: '剛剛！馬雲正式宣佈開放餘額寶！4.7億人喜極而泣！',
#  542: '碧生源(00926)擬溢價9.89%發行2.93億股予Aurum Credo募資1.46億港元',
#  543: '2018千人小程序峰會',
#  544: '假如你的資產超過1000萬，還需要出來工作或者上班嗎？怎麼安排比較好？',
#  545: '農業銀行日照嵐山支行舉辦青年演講比賽',
#  546: '無抵押貸款都有哪些途徑？',
#  547: '沒有雄厚資金的創業者，如何最大程度提高成功創業幾率？',
#  548: '驚恐「套路貸」是如何毀掉一個人的？',
#  549: '「老乾媽」陶華碧恪守「堅決不上市」，你怎麼看？',
#  550: '辦理下來的工商銀行信用卡剛額度有多少？',
#  551: '怎麼來尋找和選擇合適的投資商？',
#  552: '如何對大腦進行投資該投資什麼？',
#  553: '這篇關於馬雲的文章，受益匪淺，我都看了很多遍了',
#  554: '雪迪龍這家公司的股價為什麼一直走低？',
#  555: '玉米價格還會繼續回落嗎？',
#  556: '鄭眼看盤：醫藥券商白酒為何脈衝式上漲？',
#  557: '「國六」即將實施，常用的「國三」「國四」會怎樣處理呢？',
#  558: '雲聯惠為什麼會進博鰲論壇？',
#  559: '2018年全國GDP增速排名說明瞭什麼？您怎麼看？',
#  560: '這麼多公鏈崛起，到底誰能走到最後？',
#  561: '我與一帶一路沿線國家進口增速超出口',
#  562: '上市近3月消失1900億！股價瘋狂下跌至41.8%！8萬小散都傻眼了！',
#  563: '面對危機餐飲行業該如何發展？',
#  564: '被冷落後應該怎樣調整自己的心態？',
#  565: '負債累累，如何創業？',
#  566: '人民幣國際化：為「一帶一路」保駕護航',
#  567: '信用卡是這個月花下個月還，還沒有手續費，那銀行開信用卡業務是靠什麼賺錢呢？',
#  568: '快三十歲了找不到工作，也沒資金創業，該何去何從？',
#  569: '廣東琶洲展，廣交會陽江企業成交2.37億美元',
#  570: '一家信用卡逾期五個月，他行信用卡會封卡降額嗎？',
#  571: '創業你沒錢？不創業你更沒錢！2018那些你不知道的商機',
#  572: 'A股為何不實行T+0交易制度？',
#  573: '唯獨一家不用明星代言的手機，就連股神巴菲特都力挺！',
#  574: '炒股天才的肺腑獨白，股票書上無法學到的精髓，練到極致就是絕活',
#  575: '那些可以一把梭的股票 都有啥特徵',
#  576: '莊家出貨不是在高位出貨的嗎，為什麼要砸盤到跌停出貨呢？',
#  577: '飛機票退改簽手續費誰說了算？是否屬於霸王條款？',
#  578: '美國國債也是借新錢還舊錢，是不是龐氏騙局？',
#  579: '為什麼有錢人理財能10倍100倍增長，而我們理財原地踏步10年不動呢？',
#  580: '巴菲特說股票交易是一個簡單理念的堅持，你是怎麼看的？',
#  581: '2018.5.7經濟解讀',
#  582: '當你所做的一切都因為「錢」而止住時，身無分文，該如何解決眼前的困境？',
#  583: '為什麼很多人炒股同時用很多台電腦？',
#  584: '有哪些不被看好的行業正在崛起？',
#  585: '有人說買房貸款越多越好、還款時間越久越好，真的是這樣嗎？',
#  586: '莊家在買二買三掛大買單托單是想幹什麼？',
#  587: '一批重磅新規今天正式實施',
#  588: '廣州紅酒進口報關報檢',
#  589: '在股票市場當中，如何建立完整的趨勢交易系統？',
#  590: '輕型客車增幅最大！宇通前4月銷售各類客車1.3萬輛',
#  591: '賣氣味竟賣出3個億！她靠8萬塊創業成功，張藝謀、奔馳、杜蕾斯都是客戶',
#  592: '為什麼A股投資者越保護越虧？',
#  593: '有什麼項目可以投資，但不用自己盯著？',
#  594: '二銨出口外高內低 後市或可期？',
#  595: '下周大盤可能暴跌1000點',
#  596: '晚清的GDP世界第一，是日本的5倍，為什麼還打不贏日本？',
#  597: '國際油價降至兩周最低，下一輪油價調整會下跌嗎？',
#  598: '餘額寶升級後，有兩只新的貨幣基金，分別是博時基金和中歐基金管理，對用戶有什麼風險嗎？',
#  599: '罰款逾1.8億！銀保監會開出首批銀行大罰單，招行、興業、浦發中招',
#  600: '蘋果公司現金流近三千億美元，會有收購阿里巴巴的可能性嗎？',
#  601: '15 分鐘參透比特幣和區塊鏈',
#  602: '微信支付是否已遠遠超過支付寶？',
#  603: '如果騰訊不再免費，QQ和微信月租50元，中國還會有多少人繼續用？',
#  604: '如果所有銀行不讓支付寶綁定銀行卡了，支付寶會怎樣？',
#  605: '馬化騰回應騰訊沒有夢想，他回應說的話符合他一直做的嗎？',
#  606: '京東市值3個月蒸發1200億，為何屢遭機構唱空？',
#  607: '未來取代app通信的方向在哪裡？',
#  608: '阿里巴巴準備擴張東南亞市場',
#  609: 'Fullestop調研VR技術在不同行業都存在影響力',
#  610: '網友數博會：大數據與實體經濟融合發展，貴州煥發新動力',
#  611: '手機天氣軟件哪個最好？',
#  612: '淨網2018，打擊網絡黑色產業鏈',
#  613: '你如何看待央視盛贊支付寶？',
#  614: '玉米在播種前，需要二次包衣嗎，為什麼呢？',
#  615: '偶爾玩遊戲，小米mix2續航怎麼樣？',
#  616: '北京西二旗月薪5萬的程序員真實生活狀態什麼樣子的？',
#  617: '深圳地鐵「掃碼過閘」下週二正式上線',
#  618: '哪些行為在產品開發中是耍流氓？',
#  619: '聯想被踢出恆生指數，是什麼導致了聯想現在的這種境地？',
#  620: '在互聯網創業需要什麼？',
#  621: '標題黨真心嚴重，把騰訊坑壞了！',
#  622: '高通驍龍845和835相比，性能有哪些提升？',
#  623: '百度和谷歌的差距在哪裡？',
#  624: '三進制計算機可以實現嗎？',
#  625: '國內投資3000億用來做芯片，夠了麼？能不能打敗高通和英特爾？',
#  626: '這個電腦配置值多少錢？',
#  627: '美團眾包以後會消失嗎？',
#  628: '新零售背景下，電商平台會發生什麼變化？',
#  629: '微信打不開了怎麼辦？',
#  630: '騰訊發佈「00後畫像報告」 顛覆我們對這一代的認知',
#  631: '持股比例僅次於雷軍，如何評價小米二號人物林斌？',
#  632: '玉米種子在播前，需要二次包衣嗎？不需要或需要，又因為什麼呢？',
#  633: '淘寶購物大家能接受48小時後發貨嗎？',
#  634: '電腦掛機軟件是真的嗎？',
#  635: '索尼哪一款手機最好用？',
#  636: '力哥爆料：如果有時光穿梭機，你最想見誰？馬雲想見的是他們',
#  637: '如果所有銀行不讓支付寶綁定銀行卡了，支付寶會怎樣？',
#  638: '2018-05-06 區塊鏈中，代碼即是法律？',
#  639: '鄰居上門問wifi密碼，怎麼有技術又不傷感情地拒絕？',
#  640: '現在最便宜的64G內存手機是1299元，未來10年，64G內存的手機能便宜到多少錢？',
#  641: '未來有一半工作被取代，文科生最吃香！李開復給父母們的3個建議',
#  642: '小米所有的產品，有哪一種的核心技術是小米自己研發的？',
#  643: '為了微信支付安全，請打開微信錢包這個功能吧',
#  644: '小米上市後市值若超過百度，會帶來哪些影響？',
#  645: '我想買探界者，探界者和昂科威一樣的軸嗎？',
#  646: '馬雲放大招，網商銀行轉賬全免費，馬化騰騰訊微眾銀行如何應對',
#  647: '支付寶又有重榜好消息，4.5億用戶終於迎來了春天',
#  648: '假如有個好產品，如何找一個好的營銷團隊？',
#  649: '為什麼台積電一個代工企業利潤率在中國只輸工行，還比蘋果高呢？',
#  650: '有哪些好用的護髮產品？',
#  651: '中科院發佈一好消息，首款雲端人工智能芯片問世，打破世界紀錄',
#  652: '小米在港上市之後，雷軍身價有多高？',
#  653: '海爾總裁周雲傑：中國智慧物流品牌日為世界貢獻中國智慧',
#  654: '企業管理軟件系統哪個好？',
#  655: '手機電量顯示100%，突然自動關機顯示沒電了，是什麼原因？',
#  656: '朱嘯虎姚勁波……互聯網大佬紛紛表態《騰訊沒有夢想》',
#  657: '一夜之間，芝麻分更新，7億支付寶用戶沸騰，你芝麻分漲了多少？',
#  658: '碼商的福音！1688把貨源搬進支付寶二維碼 進貨收錢一「碼」事',
#  659: '傳小米阿里舜宇等八家公司列首批CDR名單',
#  660: '如何查找靜電？',
#  661: '區塊鏈極簡史2：比特幣的轉賬機制 CCR炒幣機器人',
#  662: '工信部：我國將加快制定服裝大規模定制相關標準',
#  663: '自動駕駛、醫療、能源……一季度融資最多的人工智能公司',
#  664: '幾乎每一個銀行工作人員都勸說顧客，不要把錢存入餘額寶，對此你怎麼看？',
#  665: '用微信做淘寶客怎麼樣才能精准吸粉？',
#  666: '雷軍當年提出飛豬理論的時候，一定沒想過會這樣害人不淺！',
#  667: '黑科技領路人！三星S10再曝：100%真全面屏穩了！',
#  668: '經濟學家吳敬璉為什麼反對「不惜代價發展芯片產業」？',
#  669: '小米會佈局除cpu以外更多的芯片嗎？',
#  670: '惡搞漫畫：金融危機對生活的影響',
#  671: '查理芒格談人工智能：炒作過多 還不能大規模取代人類',
#  672: '幾乎每一個銀行工作人員都勸說顧客，不要把錢存入餘額寶，對此你怎麼看？',
#  673: '科普：使用微信付錢，這兩個安全功能一定要打開，不然後悔！',
#  674: '阿里旗下支付寶有夢想有情懷，碼商成長計劃承諾助力小微企業成長',
#  675: '阿里雲在全球處於一個什麼地位？',
#  676: '能進阿里巴巴集團做管理層領導的人，出來創業成功率能達百分之八十嗎？',
#  677: '除了華為、阿里巴巴以外，你還知道哪些稱霸世界的中國高新企業？',
#  678: '騰訊沒有夢想',
#  679: 'OTT只能賣開機？酷開網絡用活動讓廣告「玩」起來',
#  680: '高度發達的外星人有復活死人的科技嗎？',
#  681: '小程序逐漸成為人們生活一部分，微信生態規則與流量玩法 資源',
#  682: '《2018年春季深圳人才供需與流動報告》發佈，平均42人競爭一個職位！',
#  683: '店鋪開了快兩個月了，換類目後每天一兩個訪客不知道怎麼辦？',
#  684: '2018.5.6幣值排名前20 總市值突破30000億',
#  685: '如何做到更好的設計、更高的質量、更低的價格、更多的收益？',
#  686: '新買的電腦只有一個C盤，如何增加分區？',
#  687: '芝麻信用分又更新了 馬雲：給600分以上福利！你芝麻分夠嗎？',
#  688: '是充電一夜對手機損害大還是電量沒用完就充電損害大？',
#  689: '支付寶-好醫保VS微信-微醫保',
#  690: '誰有好的微信頭像可以分享？',
#  691: '有哪些我們很少關注的國家，卻有著全球前列的科技產品？',
#  692: '在淘寶上面做分銷商，怎麼發貨？',
#  693: '「國民技術」的產品都應用在什麼地方？',
#  694: '微信小程序開發需要用到哪些？',
#  695: '小米7未到！這兩款小米手機目前性價比最高，米粉：可惜買不到',
#  696: '5月5日她味紅糖亮相京東眾籌首頁',
#  697: '有什麼高逼格的微信名字？',
#  698: '怎樣做一個類似拼多多的團購+分銷的APP？',
#  699: '零基礎學開亞馬遜之一賣家後台首頁講解',
#  700: '1699的魅族m15和1268的魅族pro7標準版該選哪個？',
#  701: '蘋果6 10.5系統有必要升級到最新11的系統嗎？',
#  702: '爆發的微信小程序，電商的又一春？',
#  703: 'PS利用濾鏡製作立體文字',
#  704: '微信滴滴不能用了怎麼辦？',
#  705: '估值近千億美元！小米憑啥值這麼多錢？真相了',
#  706: '國產手機那麼好，為什麼還會有這麼多人用蘋果手機？',
#  707: '1699的魅族m15和1268的魅族pro7標準版該選哪個？',
#  708: '為什麼大學的程序設計老師不去外面公司做程序員？',
#  709: '蘋果，ipad玩絕地求生怎麼錄制精彩視頻？',
#  710: '如何上傳圖片被百度收錄？',
#  711: '老闆讓我找視頻會議系統，有什麼好的品牌軟件推薦？',
#  712: '不玩AI套路 360手機N7詮釋智能本質',
#  713: '小米max2和紅米5p，哪個好一點？',
#  714: '為什麼在我們的觀念里，外星人的科技一定會強過人類？',
#  715: '一加6手機需要搶嗎？一加的系統和小米比怎麼樣？',
#  716: '怎麼看待有人冒充馬化騰回應《騰訊沒有夢想》一文？',
#  717: '小白如何提高蘋果手機拍攝的技巧？',
#  718: '智慧農業大棚監控系統能實現哪些功能？',
#  719: '小米雷軍和格力董明珠賭約到期：全國人民作證的十億賭注算數嗎？',
#  720: '現在很多人做淘寶優惠券，如何盈利的？',
#  721: '營收是阿里的兩倍，市值等於三個沃爾瑪，利潤卻只有阿里三分之一',
#  722: '馬化騰為什麼不把南非的股份收回來？',
#  723: '一夜之間，馬雲放大招，芝麻分700，網商貸可借百萬',
#  724: '美國人抱怨：「為什麼美國沒有普及手機支付？瞧瞧人家中國！」',
#  725: '10萬創業？',
#  726: '馬化騰都站台小程序，你覺得沒機會，騰訊連接一切的野心就擺那裡',
#  727: '成功人士用華為，窮人用蘋果，屌絲用小米，事實果真如此嗎？',
#  728: '為什麼中國不能像美國針對華為手機一樣也針對美國蘋果手機禁售？',
#  729: '潛伏如果陸橋山不死，會幫助余則成當上站長嗎？',
#  730: '小米要上市了，有十萬塊錢怎麼能買到小米的股票？',
#  731: '馬化騰回應《騰訊沒有夢想》：我的理想不是賺多少錢，是做出最好的產品',
#  732: '騰訊市值超過阿里，但為什麼在各種場合上，總是感覺阿里格局更高？',
#  733: '中國人一年不買蘋果手機，蘋果會破產嗎？',
#  734: '你願意把十萬元人民幣存入支付寶，還是存入微信錢包？',
#  735: '中國有沒有能力自主研發高端芯片？',
#  736: '有什麼好的餐飲開業的營銷方案？',
#  737: '預算3000元，什麼牌子的平板電視比較好？',
#  738: 'GoogleI/O2018還有兩天就要來臨，我們期待著什麼？',
#  739: '手機行業總體疲軟的態勢下，蘋果為什麼實現了逆勢增長？',
#  740: '2018互聯網創業可行嗎？',
#  741: '支付寶里可以直接查銀行卡餘額了！',
#  742: '國內程序員那麼多，為什麼不開發一個屬於自己的編程語言？',
#  743: 'Minecraft1.1.2版本中如何讓實體方塊能穿透（玩家能穿過）？',
#  744: '如何看待微信小遊戲的爆紅，是真機遇還是偽風口？',
#  745: '誰有好的微信頭像可以分享？',
#  746: '3000到5000的手機，有什麼好的推薦？',
#  747: '區塊鏈人才緊缺，全球頂尖高校紛紛開課 中國八家高校搭上專車！',
#  748: '馬雲告誡以色列大學生：別介意出身，重要的是你做什麼',
#  749: '做算法工程師是什麼樣的體驗？',
#  750: '紅信APP真的可以領紅包？',
#  751: '現在手機網絡發展是不是過快了？',
#  752: '如果安卓也像ios一樣，不理智消費，可以申請退款，中國會有多少家公司要倒閉？',
#  753: 'GPP排他性協議引發巨大爭議，Nvidia該怎麼收場？',
#  754: '小米7支持5G嗎？',
#  755: '被拍拍貸追債什麼感覺？',
#  756: '想從事UI設計，該怎樣入手呢？',
#  757: '軸承安裝方法有哪些？',
#  758: '如果騰訊、阿里開始做農資了，你覺得會怎麼做？',
#  759: '馬化騰說騰訊沒有夢想，你還見過哪些牛人說過牛逼的話？',
#  760: '中國移動5G聯合創新中心天津開放實驗室掛牌',
#  761: '聯通最便宜的全國不限流量套餐，今天真來了！',
#  762: '2.5平的電線可以承受多少電器？',
#  763: '現代化牛場都要什麼設備？',
#  764: '什麼叫做深度學習框架，其作用是什麼？',
#  765: '人類會不會進化到遺傳記憶？',
#  766: '紅米note5待機一晚耗電10%正常嗎？',
#  767: '每天數字貨幣要聞（2018-5-6）',
#  768: '如何評價文章《騰訊沒有夢想》，騰訊是否真的在喪失產品能力變成投資公司？',
#  769: '重新定義「智能汽車」，MARVEL X能成為榮威的「史冊傳奇」嗎？',
#  770: '聯通10010人工服務老是打不通是什麼原因？',
#  771: '刺激戰場既然這麼火，為什麼要投放機器人？',
#  772: '為什麼有人說前置指紋優於後置指紋？',
#  773: '騰訊沒有夢想引發轟動，馬化騰劉熾平親自回應！你贊同誰的說法',
#  774: '低調上架，小米新機4G+64G售1099，不用搶你會不會買？',
#  775: '華為手機越來越卡？趕緊開啓這2個開關，用1輩子也不會卡！',
#  776: '性別仿真機器人出現，我們還需要異性嗎？',
#  777: '章澤天告訴我們：要想嫁得好，首先你得好！',
#  778: 'iPhone X Plus真機現身：三攝對標華為 售價超一萬 蘋果真怕了？',
#  779: '華為手機音量小，一定要按這個按鈕！趕快試試吧',
#  780: '網易——馬化騰也打不死的小強，掃地僧般的存在',
#  781: '去非洲工作一年的人回來會有什麼變化，年薪十多萬值得嗎？',
#  782: '羅永浩13點親自確認，5月15日，他要發佈2款革命性產品',
#  783: '魅族手機這個功能就值300塊，剛買手機就要學會，否則手機白買了',
#  784: '日本向中國提供半導體技術，是幫助中國對抗「科技戰」還是其他？',
#  785: '經常更換微信頭像的人是怎樣的一種心理？',
#  786: 'FF 91抵達北京，為國產做準備，賈躍亭要歸來了？',
#  787: '華為手機關掉這幾個開關，縮減手機耗電量，提高待機時間',
#  788: 'iphone6plus還能用幾年？',
#  789: '寒武紀發佈新一代AI芯片採用7納米 華為麒麟980將整入寒武紀IP',
#  790: '電視外接有源音箱有電流噪音怎麼解決？',
#  791: '網上的借貸可以用嗎？',
#  792: '從20%暴跌到0.8%僅用五年，三星手機為何會在中國遇雪崩式潰敗？',
#  793: '創新思考產生創意直至實現產品',
#  794: '雷軍向李嘉誠展示重磅新機 問了這個問題',
#  795: '小米上市後市值若超過百度，會帶來哪些影響？',
#  796: '任何指望技術來解決社會公正、公平的設想，都是幻想',
#  797: '怎樣把自媒體玩得有質量？',
#  798: '能視頻通話，能人臉識別，能語音拍照的8英吋智能音箱',
#  799: '自媒體大咖是如何利用自媒體賺錢的？',
#  800: '國內各類大中型公司正版電腦軟件使用率有多高？',
#  801: '跟萬達學管理，怎樣保質保量甚至提前完成計劃目標？',
#  802: '1699的魅族m15和1268的魅族pro7標準版該選哪個？',
#  803: '什麼軟件應用能下載各種vip視頻電影？',
#  804: '哪個牌子的pos機比較好用？',
#  805: '朋友圈里的各種信息怎麼刪除？',
#  806: '馬化騰：從寫第一行代碼開始，我的理想都是如何做出最好的產品',
#  807: '從20%暴跌到0.8%僅用五年，三星手機為何會在中國遇雪崩式潰敗？',
#  808: '虛擬貨幣-從EOS主網上線，巴菲特不看好虛擬貨幣解讀虛擬貨幣',
#  809: '2018年款iPad怎麼樣？用過的人還會選擇安卓嗎？',
#  810: '持股比例僅次於雷軍，如何評價小米二號人物林斌？',
#  811: '店鋪分銷模式，分銷寶智能化採集讓你出單變得簡單',
#  812: '如果所有銀行不讓支付寶綁定銀行卡了，支付寶會怎樣？',
#  813: '一個人說他喜歡你，心裡有你，可是從來沒打過電話，只是微信聊天，他是真心的嗎？',
#  814: '螞蟻花唄是否屬於小額貸款，會影響個人徵信嗎？',
#  815: '有什麼辦法可以下載酷狗裡面的收費歌曲呢？',
#  816: '把支付寶里的收款碼發給別人安全嗎？',
#  817: '關於《騰訊沒有夢想》',
#  818: '這一年，阿里巴巴要怎麼打破「詛咒」，實現馬雲的新零售大夢',
#  819: '如果所有銀行不讓支付寶綁定銀行卡了，支付寶會怎樣？',
#  820: '2200榮耀V10與2599榮耀10應該怎麼選？',
#  821: '下班後，有什麼可以在網上做的兼職？',
#  822: '手機挖礦app，數字幣AIC、SKU',
#  823: 'Instagram上線支付功能可在APP內直接購物，為什麼社交軟件巨頭紛紛佈局電商？',
#  824: '從20%暴跌到0.8%僅用五年，三星手機為何會在中國遇雪崩式潰敗？',
#  825: '阿里巴巴最大股東是日本銀軟嗎？',
#  826: '華為若被美國禁了芯片和系統，影響大嗎？',
#  827: '如果安卓系統手機沒有流氓軟件，安全性提高，國產機的份額是不是還會上升？',
#  828: '迷你世界移動牆怎麼做？',
#  829: '電信的業務都有什麼坑？',
#  830: '太狠了！已有城市執行！有借唄、白條記錄全都不能貸款',
#  831: '幾乎每一個銀行工作人員都勸說顧客，不要把錢存入餘額寶，對此你怎麼看？',
#  832: '中國為什麼不鼓勵混合動力汽車？',
#  833: '以後會有可能用無人機代替現在民航機嗎？',
#  834: '馬雲：阿里不願招北大清華畢業生，他們應該到中小企業',
#  835: '網易商丘誠尋合作夥伴 期待與您合作共贏！',
#  836: '拉卡拉、瑞和寶、隨行付、立刷，大家推薦哪一款？',
#  837: '逼死實體店的電商，反過來大量開實體店是為啥？',
#  838: '為什麼芯片那麼難製造？',
#  839: '就品質和質量而言，是小米好，還是OV好？',
#  840: '為什麼說「不惜一切代價發展芯片產業」是危險的？',
#  841: '為什麼在淘寶貨源里有的可以分銷有的不可以？',
#  842: '如果百度的人工智能失敗了，那麼百度將何去何從？',
#  843: '如何看待阿里釘釘CEO的言論：不知道你們10點之前下班乾嘛，不到1點不合格？',
#  844: '有什麼高逼格的微信名字？',
#  845: '經常收到銀行的辦信用卡的信息，說是白金優質用戶，是真的嗎？',
#  846: 'SSG甜蜜購：區塊鏈+電商 新零售2.0時代楊帆起航',
#  847: '微信支付是否已遠遠超過支付寶？',
#  848: '離開高通小米將會怎樣？',
#  849: '大多APP在評論區都不支持圖片格式的評論內容，是不夠剛需還是過於低頻？',
#  850: '你如何看待個人信息嚴重洩露的問題，這就是所謂的大數據嗎？',
#  851: '大家怎樣看「悅花越有」支付？',
#  852: '目前分析哲學的前沿研究內容是什麼？',
#  853: '馬雲為什麼不收清華大學生，他的回答讓每個企業家深思',
#  854: '這才是消費者想要的「共享」',
#  855: '穩定的實力，靈活的規劃，在新興虛擬貨幣中獨邁阿幣別具一格',
#  856: '騰訊的老闆馬化騰憑什麼獲得「全球最偉大領袖」的稱號？',
#  857: 'HTC的手機質量怎麼樣，用的人多不？',
#  858: '為什麼中國不能像美國針對華為手機一樣也針對美國蘋果手機禁售？',
#  859: '農特產品怎麼運用抖音營銷？',
#  860: '攜程創始人梁建章呼籲女兒隨媽媽姓，淡化男性傳宗接代觀念。對此你怎麼看？',
#  861: '100年前的世界是如何影響我們今天的生活的？',
#  862: '馬雲：阿里並不願意招清華北大畢業生，他們應該到中小企業去',
#  863: '除了華為、阿里巴巴以外，你還知道哪些稱霸世界的中國高新企業？',
#  864: '當科技遇上歷史，將會產生怎樣的化學反應？',
#  865: '世界首富告訴我們，這麼做就對了——千萬別留遺憾！',
#  866: '怎樣使用微信收付款？',
#  867: '夢想是弱者的精神支柱，騰訊要這玩意兒乾啥',
#  868: '小米百貨模式已形成，雷軍要當雜貨鋪老闆嗎？',
#  869: '獨角獸的標準',
#  870: '騰訊市值超過阿里，但為什麼在各種場合上，總是感覺阿里格局更高？',
#  871: '建一個微信小程序商城需要多少錢？',
#  872: '微信刪除並拉黑了對方，我現在再把他添加回通訊錄，對方會不會有提示？',
#  873: '現在iPhone X銷量如何？',
#  874: '我這個老電腦怎麼才能玩《吃雞》？',
#  875: '當前的大環境下，想學一門編程語言，該學什麼編程語言呢？',
#  876: '一個騰訊QQ號到底能加多少好友呢？',
#  877: '這個電腦配置值多少錢？',
#  878: '你是支持網約車還是支持出租車？',
#  879: 'pos機流量卡怎樣充值續費？',
#  880: '日本的芯片技術在世界上是什麼水平？',
#  881: '高傭聯盟和淘寶聯盟有什麼區別？',
#  882: '如果蘋果放棄IOS採用安卓將會怎樣？',
#  883: '國內程序員那麼多，為什麼不開發一個屬於自己的編程語言？',
#  884: '雀巢和星巴克？',
#  885: '華為手機銷量上漲，余承東：即使沒有美國市場，也要做世界第一！',
#  886: '《唐人街探案2》中，女黑客在監獄里組裝電腦，在現實中可行嗎？',
#  887: '誰有好的微信頭像可以分享？',
#  888: '央行發佈新規定限制移動支付，將影響每個人，支付平台壞消息來了',
#  889: '安卓版本越高有什麼好處？',
#  890: '為什麼自己做的有些交互，總是不盡如人意？',
#  891: '哪些視頻軟件的錄制效果好？',
#  892: '現在最便宜的64G內存手機是1299元，未來10年，64G內存的手機能便宜到多少錢？',
#  893: '歐洲5G已經啓動，德國電信的5G天線已經啓用；華為明年發佈5G手機',
#  894: '你選過小眾手機品牌嗎，後悔嗎？',
#  895: '二手手機號遭遇解綁難題',
#  896: '區塊鏈帶來顛覆性革命，大洋鏈Oeanc帶來顛覆性認識',
#  897: '京東天貓淘寶拼多多最簡單最有效的刷單技巧',
#  898: '聯想被踢出恆生指數，是什麼導致了聯想現在的這種境地？',
#  899: '突然！騰訊王卡拉黑阿里！',
#  900: '平邑：大麥灘的櫻桃熟了',
#  901: '越看越親切的越南，不得不說的中西文化交融之地',
#  902: '烏魯木齊開展「民族團結一家親」主題活動',
#  903: '焊不鏽鋼，鋁，銅，用那種焊槍最好？',
#  904: '渾江區有這樣一個地方，每到六、七月份竟能美成這樣……',
#  905: '世界第一偉人是誰？',
#  906: '四川遊客張某帶著六名女子在三亞沙灘燒烤被撒沙，這事你怎麼看？',
#  907: '新買的iPhone7自帶的地圖裡面為什麼會有莫名其妙的導航記錄？',
#  908: '中國堪比比薩斜塔的塔，門票不到一百！週末就去這裡了',
#  909: '日本最環保的小鎮：15年來零垃圾，一群老人靠撿樹葉年入千萬',
#  910: '他單人單騎川藏80天：到達尼泊爾 回家後媽媽都認不出他了',
#  911: '廣東今年將打造11條南粵古驛道重點線路，初夏郊遊走起~',
#  912: '我和狗狗一起參加了登山比賽，我們完成了比賽，我們勝利了',
#  913: '馬略卡島騎行的旅客指南—下',
#  914: '坐著火車去拉薩，原來是這樣的體驗……',
#  915: '湘西那邊到底有沒有蠱？',
#  916: '成都首座高空玻璃棧道五一開放，在哪？',
#  917: '洋眼看江蘇活動走進大豐',
#  918: '在日本免稅店被坑，買的東西要怎麼退貨？',
#  919: '四川遊客張某帶著六名女子在三亞沙灘燒烤被撒沙，這事你怎麼看？',
#  920: '咸陽和西安哪個城市的歷史更悠久？',
#  921: '大學畢業間隔年環遊中國，做有意義的事情',
#  922: '看過了那些大山大水，初見陽朔竟是這般感受',
#  923: '情報站｜在濟南飲一碗「大碗茶」愜意舒適！',
#  924: '洛陽和西安比，哪個城市歷史更悠久？',
#  925: '旅行時和異性拼房是一種怎樣的體驗？',
#  926: '閬中嘉陵江兩岸原生態自然風光，一個讓人來了就不想離開的地方！',
#  927: '重慶遊玩有哪些旅遊攻略？',
#  928: '農村很多算卦的據說很准，你怎麼看？',
#  929: '海口塔昌村：打造原生態農宿 探索農業觀光新業態',
#  930: '說桂林山水甲天下的人都是因為沒有到過貴州，不信你看',
#  931: '旅行時和異性拼房是一種怎樣的體驗？',
#  932: '騎車旅行到達大連晚上在海邊別墅紮營',
#  933: '外媒稱海南將成中國對外開放新窗口：繁榮或超香港',
#  934: '尼斯湖不僅有傳說中的水怪，還有美不勝收的自然風景',
#  935: '雷行記：來陝西旅遊的朋友恭喜你，華山門票降價了！',
#  936: '九月想自駕去西藏，如果我開車去，朋友坐我的車，費用怎麼算才合理？',
#  937: '廣西再建城際，不走南寧，卻連接了這兩個窮地方，1300萬人將脫貧了',
#  938: '中國最變幻莫測的公路：積雪比車高，一會下雨，一會下雪',
#  939: '泰山酒店都不便宜，20年前都100多，現在的價格你肯定想不到',
#  940: '日落霞飛蒼山遠，求下句？',
#  941: '茂陵博物一日游',
#  942: '旅遊風景電腦壁紙 適合旅遊的自然風景',
#  943: '亞洲地理位置最好的國家',
#  944: '四川遊客張某帶著六名女子在三亞沙灘燒烤被撒沙，這事你怎麼看？',
#  945: '藏南面積有多長多寬？',
#  946: '微視頻｜一分鐘領略綿竹年畫村」畫景」',
#  947: '東北雪鄉景色美，網友稱：真是一場鬥智鬥勇的旅行',
#  948: '勐景來，在拍完「爸爸去哪兒了3」後，如何做到持續吸引全國遊客？',
#  949: '旅行達人告訴你，旅行不管短途或是長途別忘了帶這些，乾淨還衛生',
#  950: '一個人去爬山合適嗎？',
#  951: '發現貴州之美，盡情享受，難以忘懷',
#  952: '護照有效期不足6個月能去普吉島嗎？',
#  953: '四川遊客張某帶著六名女子在三亞沙灘燒烤被撒沙，這事你怎麼看？',
#  954: '重慶彩色馬賽克「梯田」吸引遊人',
#  955: '五月冰城變花海，看丁香花叢中的哈爾濱',
#  956: '想帶二老去湖北遊玩，非自駕，預計花費5000，有沒有攻略路線推薦？',
#  957: '戶外直播跳舞的爽兒為什麼出鏡率那麼高？',
#  958: '「跟著大V去旅行」來到開灤，走進這座活著的博物館',
#  959: '探秘最後的香格里拉之魂，縱使錯過全世界，也不願意錯過你',
#  960: '平遙古城遊記',
#  961: '去北海道，有什麼推薦新奇的溫泉勝地嗎？',
#  962: '週末去哪兒？來安徽感受國家級絕美風景道',
#  963: '遠行吧！來一場想走就走的旅行',
#  964: '億航在西安的無人飛機秀演砸了，但並不影響繼續它的表演',
#  965: '登高投身雲海間，早晨撫摸陽光炊煙，蕩漾湖上與湖怪嬉戲',
#  966: '長汀連城兩日游，走過古城，探訪培田古民居，登頂冠豸山',
#  967: '尼山聖地孔子湖畔千人徒步 快樂行走欣賞尼山美麗風光',
#  968: '有哪些日漫中有浪漫的櫻花場景？',
#  969: '湖北宜昌：最浪漫的相親節在薰衣草花海中舉行！',
#  970: '泰山遊記——一個人的自駕之旅',
#  971: '到廣西旅行這幾個神秘秘境，讓人身臨其中，彷彿世界在腳下',
#  972: '為什麼許多中國人喜好去泰國，而不去三亞？',
#  973: '五一小長假首日：通道侗寨遊人如織',
#  974: '靠花47億維持的中國沙漠第一湖，旺季門票不下百元！',
#  975: '旅行是一種愛好，瞭解新鮮的事物',
#  976: '珠海國際會展中心斬獲行業大獎 推動珠海市會展旅遊產業加快發展',
#  977: '貴州省遵義市湄潭縣轄區內旅遊景點簡介',
#  978: '從北京自駕去新疆怎麼走合適？',
#  979: '「東方萊茵河」竟然藏在京郊這座又大又美的公園內！關鍵免費玩！',
#  980: '一輩子就一次的大四畢業，該選擇旅行還是抓緊時間實習？',
#  981: '為什麼許多中國人喜好去泰國，而不去三亞？',
#  982: '來文山玩，可以帶什麼特產？',
#  983: '全國十大重點產茶縣之一「壽寧」',
#  984: '3個月貢獻392億，中國遊客去日本卻不為旅遊觀光，到底為的什麼？',
#  985: '全國這8個5A級別的旅遊古城鎮，你去過幾個？',
#  986: '南寧城市怎麼樣？適合東北人生活嗎？',
#  987: '這就是西藏！',
#  988: '除一些必備物品外，旅行時還有哪些省空間少重量又實用的東西？',
#  989: '貴州六盤水的這幾個景點，錯過一個你都會覺得可惜！',
#  990: '他們將家豬丟棄在無人島，幾年之後，它們的生活竟是這樣的！',
#  991: '來四川旅遊必去的八大景點',
#  992: '千姿百色弄秋光，求對子？',
#  993: '為什麼要來這裡看映山紅？北京這處抗戰聖地有著悲壯的經歷',
#  994: '來一場說走就走的旅行，陝西寶雞紅河谷走起',
#  995: '四川遊客張某帶著六名女子在三亞沙灘燒烤被撒沙，這事你怎麼看？',
#  996: '農村集市上這些的東西，真的是便宜又好吃，簡直賺大了',
#  997: '全世界最出名的貓，它數第二，沒人敢數第一了吧',
#  998: '易縣最美的五月，藍色油菜花開好了',
#  999: '千人相親大會，單身的有福利來了！',
#  ...}

# %%
ALL_NEWS_CLASSES = ['體育', '財經', '科技', '旅遊', '農業', '遊戲']

# %%
MODEL_NAME = 'bert-base-chinese'

# %%
# 建立數據集
class NewsDataset(Dataset):
    def __init__(self, tokenizer, titles, classes):
        self.tokenizer = tokenizer
        self.indexes = []
        self.texts = []
        self.labels = []
        for index in titles:
            self.indexes.append(index)
            self.texts.append(titles[index])
            self.labels.append(classes[index])

    def __getitem__(self, idx):
        text = self.texts[idx]

        input = self.tokenizer(text, return_tensors='pt')
        label = torch.tensor(ALL_NEWS_CLASSES.index(self.labels[idx]))

        return input, label

    def __len__(self):
        return len(self.indexes)


def create_mini_batch(samples):
    input_ids = []
    token_type_ids = []
    attention_mask = []
    labels = []
    for s in samples:
        input_ids.append(s[0]['input_ids'].squeeze(0))
        token_type_ids.append(s[0]['token_type_ids'].squeeze(0))
        attention_mask.append(s[0]['attention_mask'].squeeze(0))
        labels.append(s[1])

    # zero pad 到同一序列長度
    input_ids = torch.nn.utils.rnn.pad_sequence(input_ids, batch_first=True, padding_value=0)
    token_type_ids = torch.nn.utils.rnn.pad_sequence(token_type_ids, batch_first=True, padding_value=0)
    attention_mask = torch.nn.utils.rnn.pad_sequence(attention_mask, batch_first=True, padding_value=0)
 
    labels = torch.stack(labels)

    return input_ids, token_type_ids, attention_mask, labels

# %%
batch_size = 32

tokenizer = BertTokenizer.from_pretrained(MODEL_NAME, do_lower_case=False)

train_dataset = NewsDataset(tokenizer, train_titles, train_classes)
valid_dataset = NewsDataset(tokenizer, valid_titles, valid_classes)

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, collate_fn=create_mini_batch, shuffle=True)
valid_loader = DataLoader(dataset=valid_dataset, batch_size=batch_size, collate_fn=create_mini_batch)

# %%
def train_batch(model, data, optimizer, device):
    model.train()
    input_ids, token_type_ids, attention_mask, labels = [d.to(device) for d in data]

    outputs = model(input_ids=input_ids, token_type_ids=token_type_ids, attention_mask=attention_mask, labels=labels)
    loss = outputs.loss

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    return loss.item()

# %%
def evaluate(model, valid_loader):
    model.eval()
    device = 'cuda' if next(model.parameters()).is_cuda else 'cpu'

    tot_count = 0
    tot_loss = 0
    tot_correct = 0

    with torch.no_grad():
        for data in valid_loader:
            input_ids, token_type_ids, attention_mask, labels = [d.to(device) for d in data]

            outputs = model(input_ids=input_ids, token_type_ids=token_type_ids, attention_mask=attention_mask, labels=labels)
            
            tot_count += input_ids.size(0)
            tot_loss += outputs.loss.item()
            tot_correct += (outputs.logits.argmax(dim=-1) == labels).sum().item()
    
    evaluation = {
        'loss': tot_loss / tot_count,
        'acc': tot_correct / tot_count
    }
    return evaluation

# %%
# 訓練模型
epochs = 5
lr = 0.0001

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = BertForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=6, return_dict=True)
model.to(device)

optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=0.1)

for epoch in range(1, epochs + 1):
    print(f'epoch: {epoch}')

    for i, train_data in enumerate(train_loader):
        loss = train_batch(model, train_data, optimizer, device)
        train_size = train_data[0].size(0)

        if i % 10 == 0:
            print('train_loss: ', loss / train_size)

    evaluation = evaluate(model, valid_loader)
    print('valid_evaluation: loss={loss}, acc={acc}'.format(**evaluation))

    scheduler.step()
# Out:
# Some weights of the model checkpoint at bert-base-chinese were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-chinese and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# epoch: 1
# train_loss:  0.06013582646846771
# train_loss:  0.022713661193847656
# train_loss:  0.028812989592552185
# train_loss:  0.027789849787950516
# train_loss:  0.01726982556283474
# train_loss:  0.012641426175832748
# valid_evaluation: loss=0.012522723814472557, acc=0.89
# epoch: 2
# train_loss:  0.01023040246218443
# train_loss:  0.012173905968666077
# train_loss:  0.014499874785542488
# train_loss:  0.0020464013796299696
# train_loss:  0.004572609439492226
# train_loss:  0.020038317888975143
# valid_evaluation: loss=0.012667245777944723, acc=0.8933333333333333
# epoch: 3
# train_loss:  0.007667989004403353
# train_loss:  0.004125501029193401
# train_loss:  0.005154577549546957
# train_loss:  0.005361606832593679
# train_loss:  0.001187838613986969
# train_loss:  0.006689980626106262
# valid_evaluation: loss=0.011159320523341497, acc=0.895
# epoch: 4
# train_loss:  0.002403319114819169
# train_loss:  0.0011242839973419905
# train_loss:  0.0007949933642521501
# train_loss:  0.009006734006106853
# train_loss:  0.004859760869294405
# train_loss:  0.006704774219542742
# valid_evaluation: loss=0.01153484359694024, acc=0.8983333333333333
# epoch: 5
# train_loss:  0.0018366426229476929
# train_loss:  0.0011958710383623838
# train_loss:  0.004142256919294596
# train_loss:  0.001099086133763194
# train_loss:  0.001012573717162013
# train_loss:  0.006677275523543358
# valid_evaluation: loss=0.011425061138967673, acc=0.895

# %%
test_text = {0: '旅行達人告訴你，旅行不管短途或是長途別忘了帶這些，乾淨還衛生'}

test_data_for_model = NewsDataset(tokenizer, test_text, ALL_NEWS_CLASSES)

# %%
# for test
with torch.no_grad():
  input_ids, token_type_ids, attention_mask, labels = create_mini_batch(test_data_for_model)
  outputs = model(input_ids=input_ids.to(device), token_type_ids=token_type_ids.to(device), attention_mask=attention_mask.to(device), labels=labels.to(device))
  print(ALL_NEWS_CLASSES[outputs[1].argmax(dim=-1)[0]])
# Out:
# 旅遊
